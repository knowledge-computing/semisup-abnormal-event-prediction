# %%
import os
import time
import numpy as np
import shutil

import warnings
warnings.filterwarnings('ignore')

import sys 
sys.path.append("..") 

import subprocess

# %% [markdown]
# ## Train

# %%
""" building models """

# ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', 
#  '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']
# ['1G4F0BP', '14VQMGH', '1NTT18927', '167X3XL3', '1NTT19535', '1NTT67246', '1NTT62166', 
# '1NTT19478', '157FU0B', '1NTT33624', '143XB8CT', '12V0BC9N', '1NTT30990', '1NTT24436', 
# '1NTT48337', '1NTT19213', '11NTMBPZ', '15CU4196', '1WEH98', '1NTT22885', '14ZI7ZUN', '1RA2O96', '1NTT18635', '1NTT62846']

networks = ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', 
            '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT18635']

larger_networks = ['1NTT19478', '1NTT19213', '1NTT18635']

for seed in [1234, 4321, 1111]:
    for i, network in enumerate(networks): # networks[1:2]):

        base_dir = '/data/yijun/NTT/'
        data_name = f'{network}_naive_itv_72'
        data_path = os.path.join(base_dir, f'graph-data/08/{data_name}')

        if not os.path.exists(data_path):
            print(network)
            continue


    #     processed_path = os.path.join(data_path, f'processed')
    #     if os.path.exists(processed_path):
    #         shutil.rmtree(processed_path)

        num_classes = 2
        h_dim = 32
        graph_h_dim = 256 
        batch_size = 32 if network not in larger_networks else 8
        random_seed = seed
        predict_func = 'SVM'
        ae_model_name = f'TGConvNGATAE_{data_name}_h{h_dim}_rs{random_seed}'

        model_name = f'TGConvNGATCluster1_{data_name}_h{h_dim}_{predict_func}_rs{random_seed}'
        res_path = os.path.join(base_dir, f'model-results-1006')    
        if not os.path.exists(res_path):
            os.mkdir(res_path)        
        res_path = os.path.join(res_path, model_name)

        # !python3.8 train.py \
        --data_path $data_path \
        --res_path $res_path \
        --model_name $model_name \
        --pretrain_model_name $ae_model_name \
        --num_classes $num_classes \
        --h_dim $h_dim \
        --batch_size $batch_size \
        --predict_func $predict_func \
        --lr 0.001 \
        --eta 1 \
        --use_unlabel \
        --device 2 \
        --random_seed $random_seed \
        --epochs 100
        
        break
    break
# Out:
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/1NTT19535_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster1_1NTT19535_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster1_1NTT19535_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT19535_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.10814627 0.89185373]
# [[ 0.48476723 -1.2546194   0.942796    0.8909129   0.72413063]
#  [ 0.62597054 -0.7072702  -0.80796987 -1.0414093   0.39455867]]
# Epoch: 0 / 100 | Train Time: 219.415 | Train Loss: 0.356943; Center Loss: 0.019866; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.158287;
# Val ACC | p0:0.958, p1:0.868, r0:0.380, r1:0.679, f1:0.487.
# Test ACC | p0:0.968, p1:0.897, r0:0.478, r1:0.759, f1:0.587.
# >>> Models have been saved.
# -24.041973 -4.986969
# -12.09446 28.260088
# -24.041973 -4.986969
# -12.09446 28.260088
# [[ 0.4847655  -1.2546206   0.9427962   0.8909167   0.7241323 ]
#  [ 0.62597126 -0.70726824 -0.8079675  -1.0414087   0.3945567 ]]
# Epoch: 1 / 100 | Train Time: 219.160 | Train Loss: 0.160377; Center Loss: 0.007992; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.080456;
# Val ACC | p0:0.965, p1:0.940, r0:0.588, r1:0.714, f1:0.645.
# Test ACC | p0:0.974, p1:0.953, r0:0.676, r1:0.793, f1:0.730.
# >>> Models have been saved.
# -20.986813 18.953482
# 43.237198 9.006107
# -20.986813 18.953482
# 43.237198 9.006107
# [[ 0.48476532 -1.2546223   0.9428009   0.89092195  0.72413325]
#  [ 0.62597024 -0.70726526 -0.8079719  -1.0414145   0.39455462]]
# Epoch: 2 / 100 | Train Time: 219.116 | Train Loss: 0.119848; Center Loss: 0.005709; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.062759;
# Val ACC | p0:0.970, p1:0.974, r0:0.778, r1:0.750, f1:0.764.
# Test ACC | p0:0.974, p1:0.974, r0:0.793, r1:0.793, f1:0.793.
# >>> Models have been saved.
# -36.587666 16.0312
# -7.3487644 -31.50584
# -36.587666 16.0312
# -7.3487644 -31.50584
# [[ 0.48476475 -1.2546238   0.94280624  0.8909275   0.72413373]
#  [ 0.62596995 -0.70726264 -0.8079767  -1.0414193   0.39455342]]
# Epoch: 3 / 100 | Train Time: 218.432 | Train Loss: 0.093780; Center Loss: 0.004175; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.052029;
# Val ACC | p0:0.979, p1:0.974, r0:0.793, r1:0.821, f1:0.807.
# Test ACC | p0:0.983, p1:0.983, r0:0.862, r1:0.862, f1:0.862.
# >>> Models have been saved.
# -28.048306 32.300655
# -12.318212 -37.65673
# -28.048306 32.300655
# -12.318212 -37.65673
# [[ 0.484765   -1.2546252   0.942811    0.8909324   0.72413445]
#  [ 0.62596923 -0.7072599  -0.8079816  -1.0414231   0.3945524 ]]
# Epoch: 4 / 100 | Train Time: 217.937 | Train Loss: 0.093590; Center Loss: 0.004176; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.051832;
# Val ACC | p0:0.971, p1:0.991, r0:0.913, r1:0.750, f1:0.824.
# Test ACC | p0:0.979, p1:0.987, r0:0.889, r1:0.828, f1:0.857.
# >>> Models have been saved.
# -61.485237 -2.8751323
# -4.6089106 -31.047028
# -61.485237 -2.8751323
# -4.6089106 -31.047028
# [[ 0.48476475 -1.2546247   0.94281566  0.89093703  0.7241338 ]
#  [ 0.6259694  -0.70725757 -0.8079845  -1.0414281   0.3945516 ]]
# Epoch: 5 / 100 | Train Time: 218.691 | Train Loss: 0.072289; Center Loss: 0.002909; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.043203;
# Val ACC | p0:0.979, p1:0.996, r0:0.958, r1:0.821, f1:0.885.
# Test ACC | p0:0.983, p1:0.987, r0:0.893, r1:0.862, f1:0.877.
# >>> Models have been saved.
# 23.31732 -35.487164
# -21.912989 13.408697
# 23.31732 -35.487164
# -21.912989 13.408697
# [[ 0.48476428 -1.2546245   0.942818    0.89094007  0.72413313]
#  [ 0.6259691  -0.707256   -0.80798745 -1.0414318   0.39455104]]
# Epoch: 6 / 100 | Train Time: 218.218 | Train Loss: 0.063450; Center Loss: 0.002458; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.038874;
# Val ACC | p0:0.983, p1:0.991, r0:0.923, r1:0.857, f1:0.889.
# Test ACC | p0:0.983, p1:0.974, r0:0.806, r1:0.862, f1:0.833.
# >>> Models have been saved.
# 33.745907 12.079407
# -35.10887 13.398336
# 33.745907 12.079407
# -35.10887 13.398336
# [[ 0.48476425 -1.254625    0.9428197   0.8909408   0.72413296]
#  [ 0.62596864 -0.7072547  -0.80798846 -1.0414321   0.39454982]]
# Epoch: 7 / 100 | Train Time: 219.759 | Train Loss: 0.053490; Center Loss: 0.001985; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.033637;
# Val ACC | p0:0.983, p1:0.996, r0:0.960, r1:0.857, f1:0.906.
# Test ACC | p0:0.983, p1:0.987, r0:0.893, r1:0.862, f1:0.877.
# >>> Models have been saved.
# -0.5230393 -29.737972
# -27.916534 1.9303758
# -0.5230393 -29.737972
# -27.916534 1.9303758
# [[ 0.48476368 -1.2546256   0.94282365  0.8909451   0.7241334 ]
#  [ 0.625968   -0.7072526  -0.80799305 -1.0414363   0.39454865]]
# Epoch: 8 / 100 | Train Time: 218.983 | Train Loss: 0.058712; Center Loss: 0.002290; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.035809;
# Val ACC | p0:0.975, p1:0.996, r0:0.957, r1:0.786, f1:0.863.
# Test ACC | p0:0.983, p1:0.987, r0:0.893, r1:0.862, f1:0.877.
# [[ 0.48476335 -1.2546257   0.9428263   0.89094794  0.7241338 ]
#  [ 0.6259681  -0.7072515  -0.8079959  -1.0414385   0.3945478 ]]
# Epoch: 9 / 100 | Train Time: 218.597 | Train Loss: 0.048823; Center Loss: 0.001709; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.031733;
# Val ACC | p0:0.983, p1:0.996, r0:0.960, r1:0.857, f1:0.906.
# Test ACC | p0:0.979, p1:0.987, r0:0.889, r1:0.828, f1:0.857.
# [[ 0.48476276 -1.2546253   0.9428276   0.8909495   0.7241331 ]
#  [ 0.62596786 -0.70725125 -0.8079979  -1.0414395   0.39454743]]
# Epoch: 10 / 100 | Train Time: 218.758 | Train Loss: 0.044739; Center Loss: 0.001473; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.030005;
# Val ACC | p0:0.979, p1:0.996, r0:0.958, r1:0.821, f1:0.885.
# Test ACC | p0:0.983, p1:0.987, r0:0.893, r1:0.862, f1:0.877.
# [[ 0.48476243 -1.2546248   0.94282943  0.8909508   0.72413254]
#  [ 0.6259677  -0.70725036 -0.8080002  -1.0414419   0.39454722]]
# Epoch: 11 / 100 | Train Time: 218.527 | Train Loss: 0.044150; Center Loss: 0.001472; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.029430;
# Val ACC | p0:0.983, p1:0.996, r0:0.960, r1:0.857, f1:0.906.
# Test ACC | p0:0.983, p1:0.987, r0:0.893, r1:0.862, f1:0.877.
# [[ 0.48476142 -1.2546244   0.9428313   0.89095336  0.7241318 ]
#  [ 0.6259674  -0.70724887 -0.8080031  -1.0414444   0.39454645]]
# Epoch: 12 / 100 | Train Time: 218.176 | Train Loss: 0.048468; Center Loss: 0.001773; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.030741;
# Val ACC | p0:0.979, p1:0.996, r0:0.958, r1:0.821, f1:0.885.
# Test ACC | p0:0.987, p1:0.987, r0:0.897, r1:0.897, f1:0.897.
# [[ 0.48476136 -1.2546242   0.9428334   0.890956    0.72413176]
#  [ 0.6259673  -0.7072484  -0.80800587 -1.0414466   0.39454654]]
# Epoch: 13 / 100 | Train Time: 219.012 | Train Loss: 0.038941; Center Loss: 0.001222; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.026721;
# Val ACC | p0:0.979, p1:0.991, r0:0.920, r1:0.821, f1:0.868.
# Test ACC | p0:0.983, p1:0.987, r0:0.893, r1:0.862, f1:0.877.
# [[ 0.48476115 -1.2546241   0.9428341   0.8909568   0.72413135]
#  [ 0.6259673  -0.7072475  -0.8080063  -1.0414474   0.3945463 ]]
# Epoch: 14 / 100 | Train Time: 218.585 | Train Loss: 0.039493; Center Loss: 0.001248; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.027008;
# Val ACC | p0:0.979, p1:0.996, r0:0.958, r1:0.821, f1:0.885.
# Test ACC | p0:0.983, p1:0.987, r0:0.893, r1:0.862, f1:0.877.
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/1NTT67246_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster1_1NTT67246_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster1_1NTT67246_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT67246_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.08801211 0.91198789]
# [[-2.0208902  -0.9717976  -0.5373523   1.0090604  -0.07451583]
#  [ 0.18716758  0.10334219  0.91759247  0.30842644  0.8094315 ]]
# Epoch: 0 / 100 | Train Time: 114.286 | Train Loss: 0.348420; Center Loss: 0.018479; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.163634;
# Val ACC | p0:0.956, p1:0.791, r0:0.216, r1:0.615, f1:0.320.
# Test ACC | p0:0.965, p1:0.788, r0:0.253, r1:0.714, f1:0.374.
# >>> Models have been saved.
# -3.293201 42.844654
# 24.354311 21.173857
# -3.293201 42.844654
# 24.354311 21.173857
# [[-2.0208988  -0.97180647 -0.53736323  1.0090625  -0.07452604]
#  [ 0.1871942   0.10335951  0.91760385  0.30841503  0.80943847]]
# Epoch: 1 / 100 | Train Time: 113.747 | Train Loss: 0.248943; Center Loss: 0.012463; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.124314;
# Val ACC | p0:0.960, p1:0.949, r0:0.517, r1:0.577, f1:0.545.
# Test ACC | p0:0.967, p1:0.957, r0:0.613, r1:0.679, f1:0.644.
# >>> Models have been saved.
# -0.5023327 57.031048
# -26.729393 -20.53264
# -0.5023327 57.031048
# -26.729393 -20.53264
# [[-2.0209117  -0.9718133  -0.5373763   1.0090638  -0.07453423]
#  [ 0.18721569  0.10337154  0.9176163   0.30840603  0.8094454 ]]
# Epoch: 2 / 100 | Train Time: 117.546 | Train Loss: 0.143052; Center Loss: 0.006915; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.073902;
# Val ACC | p0:0.978, p1:0.964, r0:0.667, r1:0.769, f1:0.714.
# Test ACC | p0:0.985, p1:0.964, r0:0.706, r1:0.857, f1:0.774.
# >>> Models have been saved.
# -14.735359 -42.598984
# -25.019081 -5.6185946
# -14.735359 -42.598984
# -25.019081 -5.6185946
# [[-2.0209298  -0.97181994 -0.53739136  1.0090653  -0.07454126]
#  [ 0.18723963  0.10338261  0.9176308   0.30839866  0.8094518 ]]
# Epoch: 3 / 100 | Train Time: 116.030 | Train Loss: 0.143330; Center Loss: 0.006913; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.074203;
# Val ACC | p0:0.961, p1:0.971, r0:0.652, r1:0.577, f1:0.612.
# Test ACC | p0:0.963, p1:0.939, r0:0.514, r1:0.643, f1:0.571.
# [[-2.0209339  -0.97182393 -0.53739715  1.0090698  -0.07454562]
#  [ 0.18725222  0.10338961  0.91763425  0.30839238  0.8094525 ]]
# Epoch: 4 / 100 | Train Time: 115.192 | Train Loss: 0.122409; Center Loss: 0.005703; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.065380;
# Val ACC | p0:0.986, p1:0.989, r0:0.880, r1:0.846, f1:0.863.
# Test ACC | p0:0.993, p1:0.989, r0:0.897, r1:0.929, f1:0.912.
# >>> Models have been saved.
# 16.326984 -37.29045
# -36.158253 -2.0116115
# 16.326984 -37.29045
# -36.158253 -2.0116115
# [[-2.0209374  -0.971826   -0.5374009   1.0090718  -0.07454812]
#  [ 0.18726476  0.10339559  0.91764086  0.3083888   0.80945534]]
# Epoch: 5 / 100 | Train Time: 113.866 | Train Loss: 0.081970; Center Loss: 0.003706; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.044912;
# Val ACC | p0:0.993, p1:0.989, r0:0.889, r1:0.923, f1:0.906.
# Test ACC | p0:0.993, p1:0.971, r0:0.765, r1:0.929, f1:0.839.
# >>> Models have been saved.
# 0.83334094 -24.573637
# -35.39898 -4.5749745
# 0.83334094 -24.573637
# -35.39898 -4.5749745
# [[-2.0209415  -0.9718284  -0.537405    1.009072   -0.07455114]
#  [ 0.18727307  0.10339995  0.91764426  0.30838543  0.80945694]]
# Epoch: 6 / 100 | Train Time: 115.184 | Train Loss: 0.059902; Center Loss: 0.002625; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.033650;
# Val ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.846, f1:0.917.
# Test ACC | p0:0.993, p1:0.996, r0:0.963, r1:0.929, f1:0.945.
# >>> Models have been saved.
# -8.338117 -35.58344
# -24.021538 18.221054
# -8.338117 -35.58344
# -24.021538 18.221054
# [[-2.0209496  -0.97183114 -0.53741086  1.009073   -0.07455397]
#  [ 0.18728304  0.10340403  0.91764843  0.30838248  0.80945915]]
# Epoch: 7 / 100 | Train Time: 116.599 | Train Loss: 0.064317; Center Loss: 0.002772; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.036593;
# Val ACC | p0:0.989, p1:1.000, r0:1.000, r1:0.885, f1:0.939.
# Test ACC | p0:0.993, p1:0.996, r0:0.963, r1:0.929, f1:0.945.
# >>> Models have been saved.
# 31.039675 30.449543
# 25.223925 -34.883514
# 31.039675 30.449543
# 25.223925 -34.883514
# [[-2.0209513  -0.9718324  -0.5374144   1.0090742  -0.0745562 ]
#  [ 0.18729137  0.10340763  0.91765285  0.30838016  0.80946136]]
# Epoch: 8 / 100 | Train Time: 113.212 | Train Loss: 0.052846; Center Loss: 0.002192; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.030930;
# Val ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.846, f1:0.917.
# Test ACC | p0:0.993, p1:0.996, r0:0.963, r1:0.929, f1:0.945.
# [[-2.0209515  -0.9718335  -0.5374169   1.0090742  -0.07455792]
#  [ 0.18729414  0.10340926  0.9176543   0.30837858  0.8094625 ]]
# Epoch: 9 / 100 | Train Time: 114.547 | Train Loss: 0.036508; Center Loss: 0.001385; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.022662;
# Val ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.846, f1:0.917.
# Test ACC | p0:0.989, p1:1.000, r0:1.000, r1:0.893, f1:0.943.
# [[-2.0209527  -0.9718346  -0.537419    1.0090746  -0.07455932]
#  [ 0.18729848  0.10341203  0.9176567   0.30837646  0.8094644 ]]
# Epoch: 10 / 100 | Train Time: 116.287 | Train Loss: 0.030320; Center Loss: 0.001093; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.019394;
# Val ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.846, f1:0.917.
# Test ACC | p0:0.989, p1:1.000, r0:1.000, r1:0.893, f1:0.943.
# [[-2.0209548  -0.9718354  -0.5374216   1.0090741  -0.07456052]
#  [ 0.18730205  0.10341343  0.91765815  0.30837557  0.80946475]]
# Epoch: 11 / 100 | Train Time: 113.510 | Train Loss: 0.030410; Center Loss: 0.001084; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.019570;
# Val ACC | p0:0.982, p1:1.000, r0:1.000, r1:0.808, f1:0.894.
# Test ACC | p0:0.993, p1:0.996, r0:0.963, r1:0.929, f1:0.945.
# [[-2.0209568  -0.97183704 -0.53742445  1.009075   -0.07456215]
#  [ 0.18730694  0.10341595  0.9176611   0.30837366  0.80946624]]
# Epoch: 12 / 100 | Train Time: 115.162 | Train Loss: 0.037440; Center Loss: 0.001467; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.022766;
# Val ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.846, f1:0.917.
# Test ACC | p0:0.993, p1:0.993, r0:0.929, r1:0.929, f1:0.929.
# [[-2.0209565  -0.9718382  -0.53742784  1.0090756  -0.07456432]
#  [ 0.18730916  0.10341793  0.91766244  0.3083724   0.8094672 ]]
# Epoch: 13 / 100 | Train Time: 114.934 | Train Loss: 0.072501; Center Loss: 0.003279; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.039706;
# Val ACC | p0:0.982, p1:0.978, r0:0.778, r1:0.808, f1:0.792.
# Test ACC | p0:0.985, p1:0.971, r0:0.750, r1:0.857, f1:0.800.
# [[-2.02097    -0.9718424  -0.53743744  1.0090773  -0.07456854]
#  [ 0.18732725  0.10342415  0.9176718   0.3083691   0.80947053]]
# Epoch: 14 / 100 | Train Time: 114.757 | Train Loss: 0.097554; Center Loss: 0.004501; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.052541;
# Val ACC | p0:0.982, p1:0.982, r0:0.808, r1:0.808, f1:0.808.
# Test ACC | p0:0.993, p1:0.986, r0:0.867, r1:0.929, f1:0.897.
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/1NTT19478_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster1_1NTT19478_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster1_1NTT19478_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 8
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT19478_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.11892291 0.88107709]
# [[-1.0192904  -0.43294615 -0.16561837  1.929489    0.18087487]
#  [ 0.85548323  0.4321414   0.19780856  0.56737036  0.29555538]]
# Epoch: 0 / 100 | Train Time: 546.852 | Train Loss: 1.174130; Center Loss: 0.094601; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.228122;
# Val ACC | p0:0.937, p1:0.963, r0:0.652, r1:0.517, f1:0.577.
# Test ACC | p0:0.913, p1:0.959, r0:0.526, r1:0.333, f1:0.408.
# >>> Models have been saved.
# -23.34763 38.011032
# 29.898699 -1.4786313
# -23.34763 38.011032
# 29.898699 -1.4786313
# [[-1.019543   -0.43303126 -0.1656572   1.929655    0.18086705]
#  [ 0.8557474   0.4322315   0.1978483   0.56704056  0.29555014]]
# Epoch: 1 / 100 | Train Time: 549.940 | Train Loss: 0.946311; Center Loss: 0.074693; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.199384;
# Val ACC | p0:0.942, p1:0.829, r0:0.327, r1:0.621, f1:0.429.
# Test ACC | p0:0.912, p1:0.854, r0:0.273, r1:0.400, f1:0.324.
# [[-1.0196913  -0.43308997 -0.16567452  1.9297132   0.18085752]
#  [ 0.8558977   0.43227062  0.1978604   0.5668685   0.29553208]]
# Epoch: 2 / 100 | Train Time: 541.443 | Train Loss: 0.596818; Center Loss: 0.045976; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.137056;
# Val ACC | p0:0.943, p1:0.991, r0:0.889, r1:0.552, f1:0.681.
# Test ACC | p0:0.930, p1:0.973, r0:0.700, r1:0.467, f1:0.560.
# >>> Models have been saved.
# -26.353065 9.820771
# -22.521362 -16.118568
# -26.353065 9.820771
# -22.521362 -16.118568
# [[-1.0197778  -0.43312642 -0.16569495  1.929725    0.18084158]
#  [ 0.8559744   0.43229708  0.19787651  0.566777    0.2955372 ]]
# Epoch: 3 / 100 | Train Time: 541.521 | Train Loss: 0.469047; Center Loss: 0.036123; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.107822;
# Val ACC | p0:0.953, p1:0.931, r0:0.559, r1:0.655, f1:0.603.
# Test ACC | p0:0.946, p1:0.959, r0:0.667, r1:0.600, f1:0.632.
# [[-1.0198796  -0.43316293 -0.16569941  1.9297547   0.18084194]
#  [ 0.8560694   0.43233046  0.19788414  0.5666656   0.2955296 ]]
# Epoch: 4 / 100 | Train Time: 540.818 | Train Loss: 0.473171; Center Loss: 0.036035; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.112821;
# Val ACC | p0:0.967, p1:0.949, r0:0.667, r1:0.759, f1:0.710.
# Test ACC | p0:0.959, p1:0.959, r0:0.700, r1:0.700, f1:0.700.
# >>> Models have been saved.
# -34.521034 -15.557149
# 36.56412 13.264742
# -34.521034 -15.557149
# 36.56412 13.264742
# [[-1.0199741  -0.43318948 -0.16571136  1.9297842   0.18083204]
#  [ 0.8561789   0.43236595  0.19790198  0.56654465  0.29553387]]
# Epoch: 5 / 100 | Train Time: 542.043 | Train Loss: 0.351413; Center Loss: 0.026607; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.085342;
# Val ACC | p0:0.935, p1:0.931, r0:0.500, r1:0.517, f1:0.508.
# Test ACC | p0:0.932, p1:0.941, r0:0.536, r1:0.500, f1:0.517.
# [[-1.0200028  -0.43320343 -0.16571768  1.9297894   0.18082502]
#  [ 0.85618526  0.43236324  0.19790131  0.56651753  0.29553652]]
# Epoch: 6 / 100 | Train Time: 541.338 | Train Loss: 0.249158; Center Loss: 0.018497; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.064188;
# Val ACC | p0:0.973, p1:0.991, r0:0.920, r1:0.793, f1:0.852.
# Test ACC | p0:0.960, p1:0.995, r0:0.955, r1:0.700, f1:0.808.
# >>> Models have been saved.
# 39.80624 7.094077
# 27.050665 -28.673996
# 39.80624 7.094077
# 27.050665 -28.673996
# [[-1.0200438  -0.43321437 -0.16572301  1.9298059   0.18081884]
#  [ 0.85623544  0.43237555  0.19790627  0.56646526  0.29553682]]
# Epoch: 7 / 100 | Train Time: 548.286 | Train Loss: 0.216947; Center Loss: 0.016016; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.056787;
# Val ACC | p0:0.981, p1:0.972, r0:0.806, r1:0.862, f1:0.833.
# Test ACC | p0:0.968, p1:0.977, r0:0.821, r1:0.767, f1:0.793.
# [[-1.0202285  -0.4333086  -0.1657596   1.9298288   0.18078062]
#  [ 0.8565706   0.4325096   0.19796108  0.5661967   0.29555485]]
# Epoch: 8 / 100 | Train Time: 553.309 | Train Loss: 0.435871; Center Loss: 0.033932; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.096555;
# Val ACC | p0:0.968, p1:0.843, r0:0.404, r1:0.793, f1:0.535.
# Test ACC | p0:0.955, p1:0.872, r0:0.429, r1:0.700, f1:0.532.
# [[-1.020352   -0.4333602  -0.16577609  1.9298841   0.1807708 ]
#  [ 0.8565361   0.43249744  0.19796857  0.56615585  0.295555  ]]
# Epoch: 9 / 100 | Train Time: 550.200 | Train Loss: 0.344223; Center Loss: 0.026070; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.083520;
# Val ACC | p0:0.958, p1:0.949, r0:0.645, r1:0.690, f1:0.667.
# Test ACC | p0:0.964, p1:0.968, r0:0.759, r1:0.733, f1:0.746.
# [[-1.0204645  -0.4333961  -0.16578142  1.9299377   0.18077119]
#  [ 0.85651976  0.43248767  0.19796216  0.5661222   0.29555467]]
# Epoch: 10 / 100 | Train Time: 550.836 | Train Loss: 0.605108; Center Loss: 0.046850; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.136611;
# Val ACC | p0:0.961, p1:0.903, r0:0.500, r1:0.724, f1:0.592.
# Test ACC | p0:0.948, p1:0.918, r0:0.514, r1:0.633, f1:0.567.
# [[-1.02055    -0.43343452 -0.16579655  1.9300276   0.18077458]
#  [ 0.85637903  0.43244448  0.1979434   0.5662258   0.2955418 ]]
# Epoch: 11 / 100 | Train Time: 548.521 | Train Loss: 0.662167; Center Loss: 0.050200; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.160165;
# Val ACC | p0:0.960, p1:0.995, r0:0.952, r1:0.690, f1:0.800.
# Test ACC | p0:0.927, p1:0.986, r0:0.812, r1:0.433, f1:0.565.
# [[-1.0206523  -0.43348908 -0.16582207  1.9300812   0.18076244]
#  [ 0.85652006  0.43250644  0.19796897  0.56606257  0.29554266]]
# Epoch: 12 / 100 | Train Time: 552.075 | Train Loss: 0.693869; Center Loss: 0.053704; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.156825;
# Val ACC | p0:0.961, p1:0.908, r0:0.512, r1:0.724, f1:0.600.
# Test ACC | p0:0.950, p1:0.945, r0:0.613, r1:0.633, f1:0.623.
# [[-1.0207306  -0.43352765 -0.16584338  1.9301225   0.18075146]
#  [ 0.8566308   0.4325367   0.19797729  0.56594825  0.29554477]]
# Epoch: 13 / 100 | Train Time: 549.781 | Train Loss: 0.420392; Center Loss: 0.032537; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.095019;
# Val ACC | p0:0.956, p1:0.903, r0:0.488, r1:0.690, f1:0.571.
# Test ACC | p0:0.963, p1:0.941, r0:0.629, r1:0.733, f1:0.677.
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/143XB8CT_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster1_143XB8CT_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster1_143XB8CT_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_143XB8CT_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.02494693 0.97505307]
# Traceback (most recent call last):
#   File "train.py", line 145, in <module>
#     trainer.train()
#   File "../semi_supervised_AD/trainer/tgconv_ngat_cluster_trainer1.py", line 141, in train
#     unsup_node_emb, unsup_graph_emb, unsup_out = self.model(unsup_data)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "../semi_supervised_AD/models/tgconv_ngat.py", line 112, in forward
#     node_emb = self.embed_node(input_data)
#   File "../semi_supervised_AD/models/tgconv_ngat.py", line 74, in embed_node
#     node_emb = self.encoder(x, batch=input_data.batch,
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "../semi_supervised_AD/models/tgconv_ngat_base.py", line 74, in forward
#     out_0_i = self._graph_conv(out_0_i, edge_index, edge_weight)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/gat_conv.py", line 152, in forward
#     out = self.propagate(edge_index, x=(x_l, x_r),
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/message_passing.py", line 237, in propagate
#     out = self.message(**msg_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/gat_conv.py", line 183, in message
#     return x_j * alpha.unsqueeze(-1)
# RuntimeError: CUDA out of memory. Tried to allocate 74.00 MiB (GPU 2; 11.91 GiB total capacity; 10.84 GiB already allocated; 56.56 MiB free; 11.07 GiB reserved in total by PyTorch)
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/1NTT30990_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster1_1NTT30990_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster1_1NTT30990_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT30990_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.02130998 0.97869002]
# [[ 0.28983513 -1.2677398   0.8477749   0.8445727   0.17473519]
#  [-0.5631153   1.3312377  -1.1858032   1.7732614  -0.01637216]]
# Epoch: 0 / 100 | Train Time: 82.488 | Train Loss: 0.185900; Center Loss: 0.008964; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.096258;
# Val ACC | p0:0.983, p1:0.728, r0:0.033, r1:0.429, f1:0.062.
# Test ACC | p0:0.980, p1:0.771, r0:0.033, r1:0.333, f1:0.060.
# >>> Models have been saved.
# 13.613779 17.737835
# -2.191234 28.842623
# 13.613779 17.737835
# -2.191234 28.842623
# [[ 0.28985238 -1.2677723   0.8478091   0.8445329   0.17474273]
#  [-0.56313246  1.3312781  -1.1858367   1.7732729  -0.01638149]]
# Epoch: 1 / 100 | Train Time: 80.769 | Train Loss: 0.186068; Center Loss: 0.009032; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.095752;
# Val ACC | p0:0.982, p1:0.868, r0:0.045, r1:0.286, f1:0.078.
# Test ACC | p0:0.981, p1:0.895, r0:0.056, r1:0.267, f1:0.092.
# >>> Models have been saved.
# 31.258648 -38.34981
# 48.46933 -10.083222
# 31.258648 -38.34981
# 48.46933 -10.083222
# [[ 0.28985563 -1.2677771   0.8478155   0.8445258   0.17474441]
#  [-0.5631394   1.3312893  -1.1858488   1.773279   -0.01638352]]
# Epoch: 2 / 100 | Train Time: 80.444 | Train Loss: 0.158584; Center Loss: 0.007323; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.085353;
# Val ACC | p0:0.983, p1:0.790, r0:0.036, r1:0.357, f1:0.065.
# Test ACC | p0:0.982, p1:0.825, r0:0.042, r1:0.333, f1:0.075.
# [[ 0.28986177 -1.2677928   0.84783065  0.84451073  0.17474428]
#  [-0.5631433   1.3312997  -1.1858568   1.7732815  -0.01638531]]
# Epoch: 3 / 100 | Train Time: 83.168 | Train Loss: 0.146971; Center Loss: 0.006874; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.078228;
# Val ACC | p0:0.983, p1:0.927, r0:0.078, r1:0.286, f1:0.123.
# Test ACC | p0:0.982, p1:0.955, r0:0.121, r1:0.267, f1:0.167.
# >>> Models have been saved.
# -12.894067 54.1608
# 0.786284 -50.573605
# -12.894067 54.1608
# 0.786284 -50.573605
# [[ 0.2898657  -1.2677953   0.8478343   0.84450763  0.17474464]
#  [-0.56314594  1.3312984  -1.1858566   1.7732755  -0.016387  ]]
# Epoch: 4 / 100 | Train Time: 82.645 | Train Loss: 0.127636; Center Loss: 0.005260; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.075031;
# Val ACC | p0:0.985, p1:0.907, r0:0.077, r1:0.357, f1:0.127.
# Test ACC | p0:0.983, p1:0.924, r0:0.093, r1:0.333, f1:0.145.
# >>> Models have been saved.
# -29.87767 39.439636
# 3.7612317 -39.648144
# -29.87767 39.439636
# 3.7612317 -39.648144
# [[ 0.2898666  -1.2677957   0.8478355   0.84450084  0.17474492]
#  [-0.5631495   1.3313059  -1.1858641   1.7732797  -0.01638842]]
# Epoch: 5 / 100 | Train Time: 81.079 | Train Loss: 0.122063; Center Loss: 0.005094; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.071120;
# Val ACC | p0:0.984, p1:0.888, r0:0.065, r1:0.357, f1:0.110.
# Test ACC | p0:0.985, p1:0.893, r0:0.080, r1:0.400, f1:0.133.
# [[ 0.28986868 -1.2677954   0.8478372   0.8444978   0.1747452 ]
#  [-0.5631525   1.3313117  -1.1858705   1.7732788  -0.01638922]]
# Epoch: 6 / 100 | Train Time: 80.373 | Train Loss: 0.105288; Center Loss: 0.004409; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.061197;
# Val ACC | p0:0.986, p1:0.896, r0:0.082, r1:0.429, f1:0.138.
# Test ACC | p0:0.983, p1:0.896, r0:0.069, r1:0.333, f1:0.115.
# >>> Models have been saved.
# 20.961502 62.862896
# 12.396276 16.406307
# 20.961502 62.862896
# 12.396276 16.406307
# [[ 0.28986737 -1.2677894   0.8478339   0.8444961   0.17474435]
#  [-0.5631529   1.3313085  -1.1858691   1.7732786  -0.01638948]]
# Epoch: 7 / 100 | Train Time: 80.753 | Train Loss: 0.093792; Center Loss: 0.003942; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.054373;
# Val ACC | p0:0.987, p1:0.910, r0:0.094, r1:0.429, f1:0.154.
# Test ACC | p0:0.983, p1:0.924, r0:0.093, r1:0.333, f1:0.145.
# >>> Models have been saved.
# -28.930595 14.333067
# 16.988195 28.907436
# -28.930595 14.333067
# 16.988195 28.907436
# [[ 0.28986996 -1.2677906   0.84783846  0.844486    0.17474353]
#  [-0.56315804  1.3313174  -1.1858792   1.7732847  -0.01639049]]
# Epoch: 8 / 100 | Train Time: 80.235 | Train Loss: 0.088782; Center Loss: 0.004010; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.048681;
# Val ACC | p0:0.985, p1:0.927, r0:0.096, r1:0.357, f1:0.152.
# Test ACC | p0:0.982, p1:0.947, r0:0.105, r1:0.267, f1:0.151.
# [[ 0.2898725  -1.2677927   0.8478433   0.8444783   0.17474283]
#  [-0.56316227  1.3313272  -1.185887    1.7732887  -0.01639142]]
# Epoch: 9 / 100 | Train Time: 83.728 | Train Loss: 0.089127; Center Loss: 0.004145; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.047681;
# Val ACC | p0:0.984, p1:0.876, r0:0.059, r1:0.357, f1:0.101.
# Test ACC | p0:0.983, p1:0.902, r0:0.074, r1:0.333, f1:0.120.
# [[ 0.28987285 -1.2677885   0.8478412   0.8444758   0.17474264]
#  [-0.56316394  1.3313274  -1.185888    1.77329    -0.01639176]]
# Epoch: 10 / 100 | Train Time: 81.625 | Train Loss: 0.084532; Center Loss: 0.003771; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.046824;
# Val ACC | p0:0.985, p1:0.910, r0:0.079, r1:0.357, f1:0.130.
# Test ACC | p0:0.985, p1:0.929, r0:0.115, r1:0.400, f1:0.179.
# [[ 0.28987342 -1.2677864   0.8478414   0.8444717   0.17474203]
#  [-0.56316453  1.3313262  -1.1858883   1.7732915  -0.01639181]]
# Epoch: 11 / 100 | Train Time: 80.101 | Train Loss: 0.073651; Center Loss: 0.003252; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.041131;
# Val ACC | p0:0.986, p1:0.902, r0:0.087, r1:0.429, f1:0.145.
# Test ACC | p0:0.983, p1:0.924, r0:0.093, r1:0.333, f1:0.145.
# [[ 0.28987414 -1.2677834   0.8478408   0.844469    0.17474215]
#  [-0.5631665   1.3313274  -1.185891    1.7732929  -0.01639247]]
# Epoch: 12 / 100 | Train Time: 82.269 | Train Loss: 0.070365; Center Loss: 0.003217; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.038195;
# Val ACC | p0:0.985, p1:0.913, r0:0.082, r1:0.357, f1:0.133.
# Test ACC | p0:0.983, p1:0.912, r0:0.081, r1:0.333, f1:0.130.
# [[ 0.28987464 -1.2677824   0.8478409   0.84446764  0.17474207]
#  [-0.5631687   1.3313324  -1.1858956   1.7732928  -0.01639286]]
# Epoch: 13 / 100 | Train Time: 80.110 | Train Loss: 0.075326; Center Loss: 0.003507; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.040257;
# Val ACC | p0:0.987, p1:0.939, r0:0.133, r1:0.429, f1:0.203.
# Test ACC | p0:0.983, p1:0.964, r0:0.148, r1:0.267, f1:0.190.
# >>> Models have been saved.
# 15.683551 -43.946053
# 6.4977508 64.19614
# 15.683551 -43.946053
# 6.4977508 64.19614
# [[ 0.28987506 -1.267785    0.8478442   0.8444643   0.17474188]
#  [-0.56316954  1.331334   -1.1858982   1.7732935  -0.01639291]]
# Epoch: 14 / 100 | Train Time: 81.542 | Train Loss: 0.067158; Center Loss: 0.003069; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.036468;
# Val ACC | p0:0.987, p1:0.914, r0:0.098, r1:0.429, f1:0.160.
# Test ACC | p0:0.986, p1:0.952, r0:0.162, r1:0.400, f1:0.231.
# [[ 0.28987533 -1.26778     0.84784263  0.8444618   0.17474188]
#  [-0.56317055  1.331331   -1.1858982   1.7732949  -0.01639345]]
# Epoch: 15 / 100 | Train Time: 79.770 | Train Loss: 0.063040; Center Loss: 0.002859; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.034455;
# Val ACC | p0:0.987, p1:0.942, r0:0.140, r1:0.429, f1:0.211.
# Test ACC | p0:0.986, p1:0.966, r0:0.214, r1:0.400, f1:0.279.
# >>> Models have been saved.
# 10.23591 -65.69996
# -21.069218 64.573975
# 10.23591 -65.69996
# -21.069218 64.573975
# [[ 0.28987464 -1.2677772   0.84784144  0.8444605   0.17474169]
#  [-0.56317174  1.3313309  -1.1858991   1.7732958  -0.01639364]]
# Epoch: 16 / 100 | Train Time: 80.803 | Train Loss: 0.063924; Center Loss: 0.002977; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.034156;
# Val ACC | p0:0.987, p1:0.936, r0:0.128, r1:0.429, f1:0.197.
# Test ACC | p0:0.984, p1:0.955, r0:0.147, r1:0.333, f1:0.204.
# [[ 0.2898763 -1.267777   0.8478429  0.8444578  0.1747418]
#  [-0.5631733  1.3313328 -1.1859014  1.7732978 -0.016394 ]]
# Epoch: 17 / 100 | Train Time: 81.305 | Train Loss: 0.062315; Center Loss: 0.002826; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.034056;
# Val ACC | p0:0.987, p1:0.928, r0:0.115, r1:0.429, f1:0.182.
# Test ACC | p0:0.982, p1:0.946, r0:0.103, r1:0.267, f1:0.148.
# [[ 0.28987578 -1.2677748   0.8478419   0.84445643  0.17474166]
#  [-0.5631738   1.3313335  -1.185902    1.7732978  -0.01639428]]
# Epoch: 18 / 100 | Train Time: 80.083 | Train Loss: 0.058255; Center Loss: 0.002671; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.031546;
# Val ACC | p0:0.985, p1:0.939, r0:0.114, r1:0.357, f1:0.172.
# Test ACC | p0:0.986, p1:0.958, r0:0.182, r1:0.400, f1:0.250.
# [[ 0.28987545 -1.2677735   0.8478416   0.84445494  0.17474188]
#  [-0.5631746   1.3313335  -1.1859024   1.7732996  -0.01639439]]
# Epoch: 19 / 100 | Train Time: 81.970 | Train Loss: 0.070599; Center Loss: 0.003240; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.038196;
# Val ACC | p0:0.985, p1:0.947, r0:0.128, r1:0.357, f1:0.189.
# Test ACC | p0:0.986, p1:0.950, r0:0.158, r1:0.400, f1:0.226.
# [[ 0.28987515 -1.2677715   0.84784126  0.8444532   0.17474054]
#  [-0.56317586  1.3313352  -1.1859037   1.7733005  -0.01639445]]
# Epoch: 20 / 100 | Train Time: 80.235 | Train Loss: 0.056713; Center Loss: 0.002564; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.031078;
# Val ACC | p0:0.987, p1:0.936, r0:0.128, r1:0.429, f1:0.197.
# Test ACC | p0:0.985, p1:0.941, r0:0.136, r1:0.400, f1:0.203.
# [[ 0.28987557 -1.2677729   0.84784317  0.84445     0.17473973]
#  [-0.56317705  1.3313401  -1.1859076   1.7733022  -0.01639418]]
# Epoch: 21 / 100 | Train Time: 80.828 | Train Loss: 0.068567; Center Loss: 0.003140; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.037169;
# Val ACC | p0:0.985, p1:0.904, r0:0.075, r1:0.357, f1:0.123.
# Test ACC | p0:0.985, p1:0.907, r0:0.091, r1:0.400, f1:0.148.
# [[ 0.28987437 -1.2677643   0.84783787  0.8444504   0.17473926]
#  [-0.56317604  1.3313338  -1.1859043   1.7733022  -0.016394  ]]
# Epoch: 22 / 100 | Train Time: 81.130 | Train Loss: 0.054336; Center Loss: 0.002436; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.029971;
# Val ACC | p0:0.987, p1:0.927, r0:0.113, r1:0.429, f1:0.179.
# Test ACC | p0:0.985, p1:0.941, r0:0.136, r1:0.400, f1:0.203.
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/1NTT48337_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster1_1NTT48337_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster1_1NTT48337_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT48337_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.0479004 0.9520996]
# [[-0.8827662  -0.84463745  2.2762203  -0.37740958  0.39960343]
#  [-0.07700618 -1.2935904   1.8327674  -0.4451485   0.37107623]]
# Epoch: 0 / 100 | Train Time: 223.712 | Train Loss: 0.216831; Center Loss: 0.011128; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.105550;
# Val ACC | p0:0.967, p1:0.905, r0:0.162, r1:0.375, f1:0.226.
# Test ACC | p0:0.976, p1:0.881, r0:0.220, r1:0.611, f1:0.324.
# >>> Models have been saved.
# 38.653965 38.31322
# 27.572834 -20.221098
# 38.653965 38.31322
# 27.572834 -20.221098
# [[-0.8827719  -0.84463197  2.2762115  -0.37740946  0.3996063 ]
#  [-0.07699639 -1.293588    1.83275    -0.44514757  0.37107038]]
# Epoch: 1 / 100 | Train Time: 223.081 | Train Loss: 0.160948; Center Loss: 0.006947; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.091479;
# Val ACC | p0:0.976, p1:0.892, r0:0.205, r1:0.562, f1:0.300.
# Test ACC | p0:0.984, p1:0.936, r0:0.382, r1:0.722, f1:0.500.
# >>> Models have been saved.
# 37.829597 21.277948
# 20.21364 -29.159653
# 37.829597 21.277948
# 20.21364 -29.159653
# [[-0.88277507 -0.8446286   2.276212   -0.37740892  0.39960635]
#  [-0.07699164 -1.2935858   1.832737   -0.44514605  0.37106815]]
# Epoch: 2 / 100 | Train Time: 223.680 | Train Loss: 0.129270; Center Loss: 0.005578; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.073487;
# Val ACC | p0:0.977, p1:0.920, r0:0.257, r1:0.562, f1:0.353.
# Test ACC | p0:0.984, p1:0.930, r0:0.361, r1:0.722, f1:0.481.
# >>> Models have been saved.
# -71.47235 22.960356
# 47.37805 17.172258
# -71.47235 22.960356
# 47.37805 17.172258
# [[-0.8827718  -0.84461296  2.2761889  -0.3774095   0.39961505]
#  [-0.07698555 -1.2935965   1.8327336  -0.4451412   0.37104657]]
# Epoch: 3 / 100 | Train Time: 224.288 | Train Loss: 0.261544; Center Loss: 0.015054; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.111000;
# Val ACC | p0:0.974, p1:0.914, r0:0.222, r1:0.500, f1:0.308.
# Test ACC | p0:0.968, p1:0.914, r0:0.222, r1:0.444, f1:0.296.
# [[-0.8827745  -0.8446064   2.2761793  -0.37740907  0.3996142 ]
#  [-0.07698021 -1.2935971   1.8327289  -0.4451396   0.3710446 ]]
# Epoch: 4 / 100 | Train Time: 223.240 | Train Loss: 0.132289; Center Loss: 0.005931; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.072978;
# Val ACC | p0:0.976, p1:0.988, r0:0.667, r1:0.500, f1:0.571.
# Test ACC | p0:0.973, p1:0.985, r0:0.643, r1:0.500, f1:0.563.
# >>> Models have been saved.
# 59.3355 -10.435351
# -16.259708 28.193735
# 59.3355 -10.435351
# -16.259708 28.193735
# [[-0.8827746  -0.8446      2.2761707  -0.377407    0.3996128 ]
#  [-0.07697497 -1.2935987   1.8327242  -0.44514012  0.3710445 ]]
# Epoch: 5 / 100 | Train Time: 222.709 | Train Loss: 0.114585; Center Loss: 0.004616; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.068424;
# Val ACC | p0:0.977, p1:0.923, r0:0.265, r1:0.562, f1:0.360.
# Test ACC | p0:0.972, p1:0.948, r0:0.346, r1:0.500, f1:0.409.
# [[-0.8827756  -0.84459376  2.2761629  -0.37740546  0.39961126]
#  [-0.07696937 -1.2935984   1.8327186  -0.44513902  0.37104282]]
# Epoch: 6 / 100 | Train Time: 222.805 | Train Loss: 0.106744; Center Loss: 0.004366; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.063085;
# Val ACC | p0:0.981, p1:0.972, r0:0.526, r1:0.625, f1:0.571.
# Test ACC | p0:0.975, p1:0.972, r0:0.526, r1:0.556, f1:0.541.
# [[-0.88277656 -0.8445895   2.2761576  -0.37740406  0.39960966]
#  [-0.07696484 -1.2935969   1.8327128  -0.44513857  0.37104312]]
# Epoch: 7 / 100 | Train Time: 221.506 | Train Loss: 0.106054; Center Loss: 0.004390; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.062159;
# Val ACC | p0:0.977, p1:0.902, r0:0.220, r1:0.562, f1:0.316.
# Test ACC | p0:0.966, p1:0.875, r0:0.163, r1:0.444, f1:0.239.
# [[-0.8827738  -0.84458125  2.276145   -0.37740016  0.39960986]
#  [-0.07696308 -1.2936016   1.8327156  -0.44514164  0.37104154]]
# Epoch: 8 / 100 | Train Time: 219.406 | Train Loss: 0.084968; Center Loss: 0.003453; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.050436;
# Val ACC | p0:0.978, p1:0.963, r0:0.429, r1:0.562, f1:0.486.
# Test ACC | p0:0.976, p1:0.982, r0:0.625, r1:0.556, f1:0.588.
# [[-0.8827751  -0.84458053  2.276145   -0.37740013  0.39960986]
#  [-0.07696217 -1.2936018   1.8327146  -0.44514084  0.3710411 ]]
# Epoch: 9 / 100 | Train Time: 219.312 | Train Loss: 0.066609; Center Loss: 0.002523; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.041378;
# Val ACC | p0:0.985, p1:0.978, r0:0.611, r1:0.688, f1:0.647.
# Test ACC | p0:0.978, p1:0.972, r0:0.550, r1:0.611, f1:0.579.
# >>> Models have been saved.
# -0.13740024 -50.208157
# -30.890348 10.621434
# -0.13740024 -50.208157
# -30.890348 10.621434
# [[-0.88277584 -0.8445794   2.2761443  -0.37740025  0.39960963]
#  [-0.07696198 -1.2936018   1.8327146  -0.4451404   0.37104055]]
# Epoch: 10 / 100 | Train Time: 219.666 | Train Loss: 0.057383; Center Loss: 0.002122; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.036166;
# Val ACC | p0:0.982, p1:0.997, r0:0.909, r1:0.625, f1:0.741.
# Test ACC | p0:0.979, p1:0.988, r0:0.733, r1:0.611, f1:0.667.
# >>> Models have been saved.
# 46.067955 7.4156694
# -40.49842 -28.927608
# 46.067955 7.4156694
# -40.49842 -28.927608
# [[-0.8827778  -0.84457755  2.2761436  -0.37739938  0.39960954]
#  [-0.07695959 -1.2936021   1.8327129  -0.44514003  0.37104046]]
# Epoch: 11 / 100 | Train Time: 219.461 | Train Loss: 0.066054; Center Loss: 0.002665; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.039403;
# Val ACC | p0:0.982, p1:0.985, r0:0.667, r1:0.625, f1:0.645.
# Test ACC | p0:0.982, p1:0.976, r0:0.600, r1:0.667, f1:0.632.
# [[-0.88278127 -0.8445751   2.2761457  -0.37739986  0.39961013]
#  [-0.07695701 -1.2936018   1.8327091  -0.4451391   0.3710394 ]]
# Epoch: 12 / 100 | Train Time: 219.725 | Train Loss: 0.070967; Center Loss: 0.002727; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.043695;
# Val ACC | p0:0.988, p1:0.982, r0:0.667, r1:0.750, f1:0.706.
# Test ACC | p0:0.979, p1:0.985, r0:0.688, r1:0.611, f1:0.647.
# [[-0.8827824  -0.84457344  2.276147   -0.37739936  0.3996103 ]
#  [-0.0769558  -1.2936013   1.8327065  -0.4451384   0.3710385 ]]
# Epoch: 13 / 100 | Train Time: 219.596 | Train Loss: 0.060313; Center Loss: 0.002372; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.036588;

# %% [markdown]
# ## Test

# %%
""" testing a given model and generating embeddings """

base_dir = '/data/yijun/NTT'
for network in ['1NTT18927']:

    data_name = f'{network}_naive_itv_72'
    data_path = os.path.join(base_dir, f'graph-data/08/{data_name}')
    if not os.path.exists(data_path):
        continue

#     processed_path = os.path.join(data_path, f'processed')
#     if os.path.exists(processed_path):
#         shutil.rmtree(processed_path)
        
    num_classes = 2
    h_dim = 32 
    graph_h_dim = 256 
    batch_size = 16
    random_seed = 1234
    ae_model_name = 'TGConvNGATAE_1NTT18927_naive_itv_72_h32_b16_rs1234'
    
    model_name = f'TGConvNGAT_{data_name}_h{h_dim}_b{batch_size}_rs{random_seed}'
    res_path = os.path.join(base_dir, f'model-results-0912')    
    res_path = os.path.join(res_path, model_name)

    if not os.path.exists(res_path):
        continue

    # !python3.8 test.py \
    --data_path $data_path \
    --res_path $res_path \
    --model_name $model_name \
    --ae_model_name $ae_model_name \
    --num_classes $num_classes \
    --h_dim $h_dim \
    --batch_size $batch_size \
    --lr 0.001 \
    --eta 1 \
    --use_unlabel \
    --device 2 \
    --random_seed $random_seed
# Out:
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/1NTT18927_naive_itv_72
# res_path: /data/yijun/NTT/model-results-0912/TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234
# model_name: TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234
# ae_model_name: TGConvNGATAE_1NTT18927_naive_itv_72_h32_b16_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 16
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.03755801 0.96244199]
# Traceback (most recent call last):
#   File "test.py", line 43, in <module>
#     model.load_state_dict(torch.load(model_path))
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 579, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/data/yijun/NTT/model-results-0912/TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234/models/model.pkl'

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### A. Visualizing Images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# for network in ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']:

network = '1NTT18927'
model_name = f'TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234'
res_path = os.path.join(base_dir, f'model-results-0912/{model_name}')    
image_path = os.path.join(res_path, 'img')

figures = dict()
n_cols = 2

label_image, prediction_image = None, None
for i in range(20):
    f1 = os.path.join(image_path, f'{i}_label.png')    
    f2 = os.path.join(image_path, f'{i}_prediction.png')    
    if not os.path.exists(f1) or not os.path.exists(f2):
        continue
    label_image, prediction_image = f1, f2

fig = plt.figure(figsize=(15, 15))
axes = []
axes.append( fig.add_subplot(1, 2, 1) )
axes[-1].set_title(f'{network} Label')  
plt.imshow(mpimg.imread(label_image))
plt.xticks([])
plt.yticks([])

axes.append( fig.add_subplot(1, 2, 2) )
axes[-1].set_title(f'{network} Prediction')  
plt.imshow(mpimg.imread(prediction_image))

plt.xticks([])
plt.yticks([])
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6289/2091227005.py in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 import matplotlib.image as mpimg
#       3
#       4 # for network in ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']:
#       5
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in <module>
#     821 # triggering resolution of _auto_backend_sentinel.
#     822 rcParamsDefault = _rc_params_in_file(
# --> 823     cbook._get_data_path("matplotlibrc"),
#     824     # Strip leading comment.
#     825     transform=lambda line: line[1:] if line.startswith("#") else line,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in _get_data_path(*args)
#     532     ``*args`` specify a path relative to the base data path.
#     533     """
# --> 534     return Path(matplotlib.get_data_path(), *args)
#     535
#     536
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'

# %% [markdown]
# ### B. Visualizing ROC curve

# %%
from utils.plot_utils import draw_roc_curve

model_name = f'GATConv_{network}_naive_itv_60_led_0_attn1_h256_b128_shuffle'
res_path = os.path.join(base_dir, f'model-results-0316/{model_name}')    

results = np.load(os.path.join(res_path, 'result.npz'))
draw_roc_curve(results['embedding'], results['label'])

# %%
"""
data | data_path: /data/yijun/NTT/graph-data/1NTT62846_naive_itv_60_led_0
data | res_path: /data/yijun/NTT/model-results-0328/GATConvCVAE_1NTT62846_naive_itv_60_led_0_feat0_h256_b128_shuffle
weighted labels: [0.02262073 0.97737927]
Testing - p0:0.985, r0:0.858, p1:0.086, r1:0.500, f:0.147.
All - p0:0.995, r0:0.885, p1:0.138, r1:0.791, f:0.234.
"""

results = dict() 

with open('results.txt', 'r') as f:
    for line in f:
        if 'data | data_path' in line:
            data_name = line.split('/')[-1].split('_')[0]
            if results.get(data_name) is None:
                results[data_name] = dict()
        if 'data | res_path' in line:
            model_name = line.split('/')[-1]
            model_type = model_name.split('_')[0]
            num_features = int(model_name.split('_')[7][4:])
            h_dim = int(model_name.split('_')[8][1:])
            batch_size = int(model_name.split('_')[9][1:])            
        if 'Testing' in line:
            items = line.split(':')
            results[data_name][(model_type, num_features, h_dim, batch_size, 'p0')] = float(items[1][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'r0')] = float(items[2][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'p1')] = float(items[3][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'r1')] = float(items[4][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'f1')] = float(items[5][:5])

# %%
import pandas as pd

results=pd.DataFrame.from_dict(results, orient='index')
results.to_csv('results.csv')

# %%
NTT/graph03/anomaly_detection/results.csv
