# %%
import os
import time
import numpy as np
import shutil

import warnings
warnings.filterwarnings('ignore')

import sys 
sys.path.append("..") 

import subprocess

# %% [markdown]
# ## Train

# %%
""" building models """

# ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', 
#  '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']
# ['1G4F0BP', '14VQMGH', '1NTT18927', '167X3XL3', '1NTT19535', '1NTT67246', '1NTT62166', 
# '1NTT19478', '157FU0B', '1NTT33624', '143XB8CT', '12V0BC9N', '1NTT30990', '1NTT24436', 
# '1NTT48337', '1NTT19213', '11NTMBPZ', '15CU4196', '1WEH98', '1NTT22885', '14ZI7ZUN', '1RA2O96', '1NTT18635', '1NTT62846']

networks = ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', 
            '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT18635']

larger_networks = ['1NTT19478', '1NTT19213', '1NTT18635']

for i, network in enumerate(networks): # networks[1:2]):

    base_dir = '/data/yijun/NTT/'
    data_name = f'{network}_naive_itv_72'
    data_path = os.path.join(base_dir, f'graph-data/08/{data_name}')
    
    if not os.path.exists(data_path):
        print(network)
        continue        
    
#     processed_path = os.path.join(data_path, f'processed')
#     if os.path.exists(processed_path):
#         shutil.rmtree(processed_path)

    num_classes = 2
    h_dim = 32
    graph_h_dim = 256 
    batch_size = 32 if network not in larger_networks else 8
    random_seed = 1234
    predict_func = 'SVM'
    ae_model_name = f'TGConvNGATAE_{data_name}_h{h_dim}_rs{random_seed}'
    
    model_name = f'TGConvNGATCluster2_{data_name}_h{h_dim}_{predict_func}_rs{random_seed}'
    res_path = os.path.join(base_dir, f'model-results-1006')    
    if not os.path.exists(res_path):
        os.mkdir(res_path)        
    res_path = os.path.join(res_path, model_name)
    
    # !python3.8 train.py \
    --data_path $data_path \
    --res_path $res_path \
    --model_name $model_name \
    --pretrain_model_name $ae_model_name \
    --num_classes $num_classes \
    --h_dim $h_dim \
    --batch_size $batch_size \
    --predict_func $predict_func \
    --lr 0.001 \
    --eta 1 \
    --use_unlabel \
    --device 1 \
    --random_seed $random_seed \
    --epochs 100
# Out:
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT18927_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT18927_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT18927_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT18927_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.03755801 0.96244199]
# [[ 1.153771    0.03313043 -0.8436092   1.3002537  -0.04062271]
#  [-1.025222   -0.07474323 -0.20920105 -0.11468539 -0.49891868]]
# Epoch: 0 / 100 | Train Time: 172.424 | Train Loss: 0.086945; Center Loss: 0.016151; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.086945;
# Val ACC | p0:0.981, p1:0.658, r0:0.072, r1:0.680, f1:0.130.
# Test ACC | p0:0.970, p1:0.657, r0:0.052, r1:0.480, f1:0.093.
# >>> Models have been saved.
# -9.110331 67.05718
# -54.845577 -30.5425
# -9.110331 67.05718
# -54.845577 -30.5425
# [[ 1.153772    0.03313251 -0.8436079   1.3002536  -0.04062061]
#  [-1.0252264  -0.07474391 -0.20919962 -0.11468921 -0.49891952]]
# Epoch: 1 / 100 | Train Time: 173.274 | Train Loss: 0.081403; Center Loss: 0.013583; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.081403;
# Val ACC | p0:0.980, p1:0.312, r0:0.045, r1:0.840, f1:0.086.
# Test ACC | p0:0.975, p1:0.309, r0:0.043, r1:0.800, f1:0.082.
# [[ 1.1537727   0.03313197 -0.84360796  1.3002532  -0.04061966]
#  [-1.0252268  -0.07474393 -0.20919862 -0.11469133 -0.49891979]]
# Epoch: 2 / 100 | Train Time: 174.010 | Train Loss: 0.080295; Center Loss: 0.012982; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.080295;
# Val ACC | p0:0.965, p1:0.775, r0:0.046, r1:0.280, f1:0.080.
# Test ACC | p0:0.965, p1:0.741, r0:0.046, r1:0.320, f1:0.080.
# [[ 1.1537749   0.03313113 -0.84360695  1.3002526  -0.04061847]
#  [-1.0252311  -0.07474425 -0.20919771 -0.11469457 -0.4989207 ]]
# Epoch: 3 / 100 | Train Time: 170.747 | Train Loss: 0.081244; Center Loss: 0.013262; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.081244;
# Val ACC | p0:0.981, p1:0.821, r0:0.115, r1:0.600, f1:0.194.
# Test ACC | p0:0.987, p1:0.824, r0:0.137, r1:0.720, f1:0.231.
# >>> Models have been saved.
# -13.52652 54.235085
# 0.018632412 -68.5034
# -13.52652 54.235085
# 0.018632412 -68.5034
# [[ 1.1537772   0.0331311  -0.84360677  1.3002526  -0.04061762]
#  [-1.025235   -0.07474465 -0.20919618 -0.11469772 -0.4989211 ]]
# Epoch: 4 / 100 | Train Time: 168.633 | Train Loss: 0.080433; Center Loss: 0.013322; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.080433;
# Val ACC | p0:0.982, p1:0.772, r0:0.099, r1:0.640, f1:0.171.
# Test ACC | p0:0.974, p1:0.825, r0:0.089, r1:0.440, f1:0.149.
# [[ 1.1537778   0.0331312  -0.8436072   1.3002536  -0.04061762]
#  [-1.0252359  -0.07474466 -0.20919584 -0.11469874 -0.49892122]]
# Epoch: 5 / 100 | Train Time: 174.894 | Train Loss: 0.079065; Center Loss: 0.012210; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079065;
# Val ACC | p0:0.981, p1:0.881, r0:0.156, r1:0.560, f1:0.243.
# Test ACC | p0:0.975, p1:0.900, r0:0.135, r1:0.400, f1:0.202.
# >>> Models have been saved.
# 2.3651307 75.81943
# -1.3003707 -17.836218
# 2.3651307 75.81943
# -1.3003707 -17.836218
# [[ 1.153779    0.03313098 -0.84360635  1.3002546  -0.04061711]
#  [-1.0252396  -0.0747449  -0.20919482 -0.11470144 -0.49892205]]
# Epoch: 6 / 100 | Train Time: 174.001 | Train Loss: 0.080722; Center Loss: 0.012920; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.080722;
# Val ACC | p0:0.980, p1:0.075, r0:0.039, r1:0.960, f1:0.075.
# Test ACC | p0:1.000, p1:0.058, r0:0.040, r1:1.000, f1:0.076.
# [[ 1.1537805   0.0331312  -0.84360576  1.300255   -0.04061633]
#  [-1.0252417  -0.07474505 -0.20919429 -0.11470298 -0.49892244]]
# Epoch: 7 / 100 | Train Time: 174.385 | Train Loss: 0.079680; Center Loss: 0.012414; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079680;
# Val ACC | p0:0.956, p1:0.512, r0:0.031, r1:0.400, f1:0.057.
# Test ACC | p0:0.961, p1:0.463, r0:0.036, r1:0.520, f1:0.068.
# [[ 1.1537809   0.0331313  -0.84360546  1.3002547  -0.04061585]
#  [-1.0252411  -0.07474504 -0.20919429 -0.11470329 -0.49892244]]
# Epoch: 8 / 100 | Train Time: 168.047 | Train Loss: 0.079185; Center Loss: 0.011991; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079185;
# Val ACC | p0:0.956, p1:0.409, r0:0.033, r1:0.520, f1:0.062.
# Test ACC | p0:0.952, p1:0.370, r0:0.031, r1:0.520, f1:0.059.
# [[ 1.1537803   0.03313124 -0.8436054   1.300254   -0.04061591]
#  [-1.0252409  -0.07474512 -0.20919377 -0.11470407 -0.49892244]]
# Epoch: 9 / 100 | Train Time: 175.690 | Train Loss: 0.079446; Center Loss: 0.012175; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079446;
# Val ACC | p0:0.971, p1:0.051, r0:0.038, r1:0.960, f1:0.073.
# Test ACC | p0:0.926, p1:0.039, r0:0.036, r1:0.920, f1:0.069.
# [[ 1.1537815   0.03313108 -0.8436047   1.3002535  -0.04061522]
#  [-1.0252419  -0.0747451  -0.20919307 -0.11470591 -0.4989227 ]]
# Epoch: 10 / 100 | Train Time: 179.446 | Train Loss: 0.079967; Center Loss: 0.012452; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079967;
# Val ACC | p0:0.964, p1:0.666, r0:0.040, r1:0.360, f1:0.073.
# Test ACC | p0:0.966, p1:0.615, r0:0.043, r1:0.440, f1:0.078.
# [[ 1.1537813   0.03313099 -0.8436045   1.3002539  -0.0406151 ]
#  [-1.0252419  -0.0747451  -0.20919311 -0.11470588 -0.4989227 ]]
# Epoch: 11 / 100 | Train Time: 173.836 | Train Loss: 0.079318; Center Loss: 0.011981; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079318;
# Val ACC | p0:0.967, p1:0.729, r0:0.049, r1:0.360, f1:0.087.
# Test ACC | p0:0.970, p1:0.708, r0:0.056, r1:0.440, f1:0.099.
# [[ 1.1537818   0.03313109 -0.84360474  1.3002536  -0.04061486]
#  [-1.0252416  -0.07474508 -0.20919277 -0.11470661 -0.4989227 ]]
# Epoch: 12 / 100 | Train Time: 166.937 | Train Loss: 0.079270; Center Loss: 0.012167; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079270;
# Val ACC | p0:0.974, p1:0.058, r0:0.038, r1:0.960, f1:0.074.
# Test ACC | p0:0.917, p1:0.034, r0:0.036, r1:0.920, f1:0.069.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT19535_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT19535_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT19535_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT19535_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.10814627 0.89185373]
# Traceback (most recent call last):
#   File "train.py", line 157, in <module>
#     trainer.train()
#   File "../semi_supervised_AD/trainer/tgconv_ngat_cluster_trainer2.py", line 141, in train
#     unsup_node_emb, unsup_graph_emb, unsup_out = self.model(unsup_data)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "../semi_supervised_AD/models/tgconv_ngat.py", line 112, in forward
#     node_emb = self.embed_node(input_data)
#   File "../semi_supervised_AD/models/tgconv_ngat.py", line 74, in embed_node
#     node_emb = self.encoder(x, batch=input_data.batch,
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "../semi_supervised_AD/models/tgconv_ngat_base.py", line 74, in forward
#     out_0_i = self._graph_conv(out_0_i, edge_index, edge_weight)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/gat_conv.py", line 152, in forward
#     out = self.propagate(edge_index, x=(x_l, x_r),
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/message_passing.py", line 237, in propagate
#     out = self.message(**msg_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/gat_conv.py", line 180, in message
#     alpha = softmax(alpha, index, ptr, size_i)
# RuntimeError: The following operation failed in the TorchScript interpreter.
# Traceback of TorchScript (most recent call last):
# RuntimeError: The following operation failed in the TorchScript interpreter.
# Traceback of TorchScript (most recent call last):
# RuntimeError: CUDA out of memory. Tried to allocate 2.00 MiB (GPU 1; 11.91 GiB total capacity; 5.26 GiB already allocated; 4.56 MiB free; 5.40 GiB reserved in total by PyTorch)
#
#
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT67246_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT67246_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT67246_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT67246_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.08801211 0.91198789]
# [[ 1.5172663   0.5251726   1.2597991  -0.05911408  0.10374903]
#  [-0.70893383 -1.2434675   1.4570738  -0.80007905 -0.75567275]]
# Epoch: 0 / 100 | Train Time: 200.245 | Train Loss: 0.151447; Center Loss: 0.038804; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.151447;
# Val ACC | p0:0.965, p1:0.592, r0:0.150, r1:0.769, f1:0.252.
# Test ACC | p0:0.981, p1:0.554, r0:0.168, r1:0.893, f1:0.282.
# >>> Models have been saved.
# 20.45008 3.3152578
# -1.2799449 8.93809
# 20.45008 3.3152578
# -1.2799449 8.93809
# [[ 1.5172557   0.52517384  1.2597857  -0.05911025  0.10375024]
#  [-0.7089334  -1.2434717   1.457087   -0.80008394 -0.7556763 ]]
# Epoch: 1 / 100 | Train Time: 203.210 | Train Loss: 0.169163; Center Loss: 0.060384; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.169163;
# Val ACC | p0:0.933, p1:0.953, r0:0.350, r1:0.269, f1:0.304.
# Test ACC | p0:0.935, p1:0.924, r0:0.323, r1:0.357, f1:0.339.
# >>> Models have been saved.
# -21.515276 -37.32372
# 42.14653 15.044766
# -21.515276 -37.32372
# 42.14653 15.044766
# [[ 1.5172658   0.52518946  1.2597742  -0.05910067  0.10375693]
#  [-0.708949   -1.2434903   1.457094   -0.80009353 -0.755685  ]]
# Epoch: 2 / 100 | Train Time: 199.569 | Train Loss: 0.122599; Center Loss: 0.018504; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.122599;
# Val ACC | p0:0.965, p1:0.989, r0:0.842, r1:0.615, f1:0.711.
# Test ACC | p0:0.972, p1:0.986, r0:0.833, r1:0.714, f1:0.769.
# >>> Models have been saved.
# -20.05494 20.110752
# 5.161012 13.731649
# -20.05494 20.110752
# 5.161012 13.731649
# [[ 1.51727     0.5251909   1.259772   -0.0590989   0.10376039]
#  [-0.7089589  -1.2434939   1.457095   -0.8000961  -0.75568944]]
# Epoch: 3 / 100 | Train Time: 200.812 | Train Loss: 0.073721; Center Loss: 0.007884; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.073721;
# Val ACC | p0:0.979, p1:0.993, r0:0.909, r1:0.769, f1:0.833.
# Test ACC | p0:0.986, p1:0.993, r0:0.923, r1:0.857, f1:0.889.
# >>> Models have been saved.
# 49.71015 5.4554133
# -11.497244 -9.45177
# 49.71015 5.4554133
# -11.497244 -9.45177
# [[ 1.5172739   0.525196    1.2597698  -0.0590969   0.10376221]
#  [-0.7089662  -1.2434996   1.4570954  -0.8000986  -0.7556922 ]]
# Epoch: 4 / 100 | Train Time: 197.345 | Train Loss: 0.052312; Center Loss: 0.006320; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.052312;
# Val ACC | p0:0.979, p1:0.993, r0:0.909, r1:0.769, f1:0.833.
# Test ACC | p0:0.986, p1:0.993, r0:0.923, r1:0.857, f1:0.889.
# [[ 1.5172777   0.52519894  1.2597706  -0.0590957   0.10376317]
#  [-0.70897025 -1.2435025   1.4570959  -0.8000997  -0.7556932 ]]
# Epoch: 5 / 100 | Train Time: 191.178 | Train Loss: 0.047511; Center Loss: 0.005354; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.047511;
# Val ACC | p0:0.968, p1:0.993, r0:0.895, r1:0.654, f1:0.756.
# Test ACC | p0:0.979, p1:0.993, r0:0.917, r1:0.786, f1:0.846.
# [[ 1.517281    0.5252026   1.2597694  -0.05909402  0.10376502]
#  [-0.708977   -1.2435081   1.457096   -0.8001019  -0.7556956 ]]
# Epoch: 6 / 100 | Train Time: 204.194 | Train Loss: 0.062377; Center Loss: 0.006721; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.062377;
# Val ACC | p0:0.979, p1:0.989, r0:0.870, r1:0.769, f1:0.816.
# Test ACC | p0:0.986, p1:0.993, r0:0.923, r1:0.857, f1:0.889.
# [[ 1.5172716   0.52519983  1.2597643  -0.0590925   0.10376886]
#  [-0.7089619  -1.2434952   1.4570926  -0.8000997  -0.7556927 ]]
# Epoch: 7 / 100 | Train Time: 198.117 | Train Loss: 0.123797; Center Loss: 0.021933; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.123797;
# Val ACC | p0:0.961, p1:0.989, r0:0.833, r1:0.577, f1:0.682.
# Test ACC | p0:0.972, p1:0.986, r0:0.833, r1:0.714, f1:0.769.
# [[ 1.5172794   0.5252096   1.259762   -0.05908822  0.1037732 ]
#  [-0.70896965 -1.243502    1.457091   -0.80010116 -0.75569725]]
# Epoch: 8 / 100 | Train Time: 201.123 | Train Loss: 0.075913; Center Loss: 0.008632; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.075913;
# Val ACC | p0:0.967, p1:0.946, r0:0.531, r1:0.654, f1:0.586.
# Test ACC | p0:0.977, p1:0.928, r0:0.524, r1:0.786, f1:0.629.
# [[ 1.5172862   0.525217    1.2597601  -0.05908639  0.10377739]
#  [-0.70897716 -1.2435075   1.457091   -0.800102   -0.7557002 ]]
# Epoch: 9 / 100 | Train Time: 187.732 | Train Loss: 0.068874; Center Loss: 0.007479; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.068874;
# Val ACC | p0:0.968, p1:0.989, r0:0.850, r1:0.654, f1:0.739.
# Test ACC | p0:0.978, p1:0.975, r0:0.759, r1:0.786, f1:0.772.
# [[ 1.517291    0.52522135  1.2597595  -0.05908542  0.10377881]
#  [-0.7089818  -1.2435097   1.4570909  -0.80010223 -0.7557013 ]]
# Epoch: 10 / 100 | Train Time: 196.788 | Train Loss: 0.061742; Center Loss: 0.006503; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.061742;
# Val ACC | p0:0.968, p1:0.986, r0:0.810, r1:0.654, f1:0.723.
# Test ACC | p0:0.978, p1:0.982, r0:0.815, r1:0.786, f1:0.800.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT19478_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT19478_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT19478_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 8
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT19478_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.11892291 0.88107709]
# [[-1.2061875  -0.4674613  -0.91215396 -0.48320144 -0.87075776]
#  [-0.12251016 -0.47819504 -0.90735525 -1.0606478   0.17348146]]
# Epoch: 0 / 100 | Train Time: 915.322 | Train Loss: 0.196770; Center Loss: 0.297483; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.196770;
# Val ACC | p0:0.936, p1:0.673, r0:0.211, r1:0.655, f1:0.319.
# Test ACC | p0:0.933, p1:0.758, r0:0.254, r1:0.600, f1:0.356.
# >>> Models have been saved.
# 21.683784 -0.22008653
# 23.486408 -8.427494
# 21.683784 -0.22008653
# 23.486408 -8.427494
# [[-1.2061995  -0.46745458 -0.91215885 -0.4831815  -0.8707619 ]
#  [-0.12249987 -0.4781967  -0.90734583 -1.0606644   0.17348602]]
# Epoch: 1 / 100 | Train Time: 920.494 | Train Loss: 0.209791; Center Loss: 0.271236; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.209791;
# Val ACC | p0:0.916, p1:0.553, r0:0.157, r1:0.621, f1:0.250.
# Test ACC | p0:0.933, p1:0.639, r0:0.202, r1:0.667, f1:0.310.
# [[-1.2062275  -0.4674668  -0.9122072  -0.48319077 -0.870764  ]
#  [-0.12247534 -0.478185   -0.9072955  -1.0606408   0.17347467]]
# Epoch: 2 / 100 | Train Time: 918.704 | Train Loss: 0.197923; Center Loss: 0.156942; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.197923;
# Val ACC | p0:0.950, p1:0.871, r0:0.404, r1:0.655, f1:0.500.
# Test ACC | p0:0.957, p1:0.909, r0:0.512, r1:0.700, f1:0.592.
# >>> Models have been saved.
# 29.76577 10.022006
# -14.5569105 -7.4754043
# 29.76577 10.022006
# -14.5569105 -7.4754043
# [[-1.206241   -0.46746802 -0.91221493 -0.48319158 -0.8707687 ]
#  [-0.12247325 -0.478182   -0.9072839  -1.06063     0.17346595]]
# Epoch: 3 / 100 | Train Time: 917.879 | Train Loss: 0.128743; Center Loss: 0.086001; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.128743;
# Val ACC | p0:0.981, p1:0.954, r0:0.714, r1:0.862, f1:0.781.
# Test ACC | p0:0.982, p1:0.973, r0:0.812, r1:0.867, f1:0.839.
# >>> Models have been saved.
# 15.975128 -12.2014065
# -4.4646273 24.135633
# 15.975128 -12.2014065
# -4.4646273 24.135633
# [[-1.2062706  -0.46746972 -0.91222084 -0.4831798  -0.8707983 ]
#  [-0.12244494 -0.4781791  -0.90727615 -1.0606356   0.17349514]]
# Epoch: 4 / 100 | Train Time: 917.971 | Train Loss: 0.079230; Center Loss: 0.053711; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079230;
# Val ACC | p0:0.991, p1:0.991, r0:0.931, r1:0.931, f1:0.931.
# Test ACC | p0:0.982, p1:0.982, r0:0.867, r1:0.867, f1:0.867.
# >>> Models have been saved.
# -4.015498 16.96864
# 21.505972 -21.95562
# -4.015498 16.96864
# 21.505972 -21.95562
# [[-1.206289   -0.4674708  -0.9122237  -0.4831772  -0.8708147 ]
#  [-0.12242962 -0.4781782  -0.9072718  -1.0606334   0.17350882]]
# Epoch: 5 / 100 | Train Time: 891.337 | Train Loss: 0.049034; Center Loss: 0.032705; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.049034;
# Val ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.931, f1:0.964.
# Test ACC | p0:0.982, p1:1.000, r0:1.000, r1:0.867, f1:0.929.
# >>> Models have been saved.
# 17.348318 -22.945822
# -8.37613 42.16286
# 17.348318 -22.945822
# -8.37613 42.16286
# [[-1.2063065  -0.46747467 -0.91222775 -0.483176   -0.8708297 ]
#  [-0.12241329 -0.4781739  -0.9072671  -1.0606272   0.1735207 ]]
# Epoch: 6 / 100 | Train Time: 561.349 | Train Loss: 0.056863; Center Loss: 0.038902; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.056863;
# Val ACC | p0:0.991, p1:0.972, r0:0.818, r1:0.931, f1:0.871.
# Test ACC | p0:0.982, p1:0.986, r0:0.897, r1:0.867, f1:0.881.
# [[-1.2063203  -0.46747667 -0.91223204 -0.4831754  -0.87084436]
#  [-0.12240021 -0.4781727  -0.9072639  -1.0606221   0.17353085]]
# Epoch: 7 / 100 | Train Time: 561.956 | Train Loss: 0.039579; Center Loss: 0.026758; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.039579;
# Val ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.931, f1:0.964.
# Test ACC | p0:0.986, p1:0.991, r0:0.931, r1:0.900, f1:0.915.
# [[-1.2063365  -0.46747833 -0.91223395 -0.48317027 -0.87085927]
#  [-0.12238651 -0.47817084 -0.907262   -1.0606222   0.17354321]]
# Epoch: 8 / 100 | Train Time: 551.021 | Train Loss: 0.025695; Center Loss: 0.017680; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.025695;
# Val ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.931, f1:0.964.
# Test ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.900, f1:0.947.
# [[-1.2063618  -0.467472   -0.9122256  -0.48316163 -0.8708809 ]
#  [-0.12236384 -0.4781784  -0.907286   -1.060617    0.17356104]]
# Epoch: 9 / 100 | Train Time: 552.313 | Train Loss: 0.079480; Center Loss: 0.055731; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.079480;
# Val ACC | p0:0.916, p1:0.705, r0:0.190, r1:0.517, f1:0.278.
# Test ACC | p0:0.922, p1:0.758, r0:0.232, r1:0.533, f1:0.323.
# [[-1.2063855  -0.4674741  -0.9122443  -0.48316297 -0.87090266]
#  [-0.12234109 -0.47817492 -0.90724254 -1.0606096   0.17358063]]
# Epoch: 10 / 100 | Train Time: 552.449 | Train Loss: 0.057224; Center Loss: 0.035425; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.057224;
# Val ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.897, f1:0.945.
# Test ACC | p0:0.973, p1:1.000, r0:1.000, r1:0.800, f1:0.889.
# [[-1.2064079  -0.4674725  -0.91224545 -0.48315102 -0.87092626]
#  [-0.12232049 -0.4781753  -0.90723944 -1.0606129   0.1736003 ]]
# Epoch: 11 / 100 | Train Time: 555.003 | Train Loss: 0.030441; Center Loss: 0.016596; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.030441;
# Val ACC | p0:0.995, p1:0.995, r0:0.966, r1:0.966, f1:0.966.
# Test ACC | p0:0.991, p1:0.995, r0:0.966, r1:0.933, f1:0.949.
# >>> Models have been saved.
# -4.5384393 -10.862227
# -1.4672028 46.24717
# -4.5384393 -10.862227
# -1.4672028 46.24717
# [[-1.2064178  -0.46747243 -0.9122449  -0.48314434 -0.8709409 ]
#  [-0.12230555 -0.4781754  -0.9072397  -1.0606135   0.17361411]]
# Epoch: 12 / 100 | Train Time: 553.973 | Train Loss: 0.017555; Center Loss: 0.008947; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.017555;
# Val ACC | p0:0.995, p1:0.995, r0:0.966, r1:0.966, f1:0.966.
# Test ACC | p0:0.991, p1:0.995, r0:0.966, r1:0.933, f1:0.949.
# [[-1.2064253  -0.46747246 -0.9122445  -0.4831376  -0.87095356]
#  [-0.12229323 -0.4781755  -0.90723956 -1.0606151   0.17362598]]
# Epoch: 13 / 100 | Train Time: 551.159 | Train Loss: 0.013615; Center Loss: 0.007135; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.013615;
# Val ACC | p0:0.995, p1:1.000, r0:1.000, r1:0.966, f1:0.982.
# Test ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.933, f1:0.966.
# >>> Models have been saved.
# 42.50564 94.34472
# -46.36693 -3.9985952
# 42.50564 94.34472
# -46.36693 -3.9985952
# [[-1.2064465  -0.4674741  -0.9122489  -0.48312715 -0.870977  ]
#  [-0.12226889 -0.47815916 -0.9072242  -1.0606058   0.17364724]]
# Epoch: 14 / 100 | Train Time: 551.822 | Train Loss: 0.040432; Center Loss: 0.026090; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.040432;
# Val ACC | p0:0.995, p1:1.000, r0:1.000, r1:0.966, f1:0.982.
# Test ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.933, f1:0.966.
# [[-1.2064635  -0.46747273 -0.9122485  -0.4831195  -0.8709948 ]
#  [-0.12224892 -0.47815347 -0.9072203  -1.0606092   0.17366548]]
# Epoch: 15 / 100 | Train Time: 548.532 | Train Loss: 0.024440; Center Loss: 0.013366; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.024440;
# Val ACC | p0:0.995, p1:1.000, r0:1.000, r1:0.966, f1:0.982.
# Test ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.933, f1:0.966.
# [[-1.2064697  -0.46747267 -0.9122486  -0.483113   -0.87100494]
#  [-0.12223957 -0.47815362 -0.9072199  -1.0606103   0.17367408]]
# Epoch: 16 / 100 | Train Time: 548.302 | Train Loss: 0.010922; Center Loss: 0.005159; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.010922;
# Val ACC | p0:0.995, p1:1.000, r0:1.000, r1:0.966, f1:0.982.
# Test ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.933, f1:0.966.
# [[-1.206483   -0.46747097 -0.9122482  -0.483107   -0.8710211 ]
#  [-0.12222474 -0.47815582 -0.90722185 -1.0606087   0.1736871 ]]
# Epoch: 17 / 100 | Train Time: 546.293 | Train Loss: 0.021970; Center Loss: 0.011696; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.021970;
# Val ACC | p0:0.995, p1:1.000, r0:1.000, r1:0.966, f1:0.982.
# Test ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.933, f1:0.966.
# [[-1.2064853  -0.46747097 -0.9122482  -0.483101   -0.8710311 ]
#  [-0.12221336 -0.47815582 -0.90722185 -1.0606087   0.17369737]]
# Epoch: 18 / 100 | Train Time: 550.590 | Train Loss: 0.008370; Center Loss: 0.003907; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.008370;
# Val ACC | p0:0.995, p1:1.000, r0:1.000, r1:0.966, f1:0.982.
# Test ACC | p0:0.986, p1:1.000, r0:1.000, r1:0.900, f1:0.947.
# [[-1.2065059  -0.46747246 -0.91225064 -0.48309043 -0.87105316]
#  [-0.1221915  -0.47815558 -0.9072168  -1.0606102   0.17371665]]
# Epoch: 19 / 100 | Train Time: 554.261 | Train Loss: 0.025213; Center Loss: 0.015048; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.025213;
# Val ACC | p0:0.991, p1:0.991, r0:0.931, r1:0.931, f1:0.931.
# Test ACC | p0:0.991, p1:0.995, r0:0.966, r1:0.933, f1:0.949.
# [[-1.2065176  -0.4674726  -0.91225183 -0.4830828  -0.8710689 ]
#  [-0.12217447 -0.47815427 -0.9072141  -1.0606129   0.17373236]]
# Epoch: 20 / 100 | Train Time: 552.067 | Train Loss: 0.018121; Center Loss: 0.008882; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.018121;
# Val ACC | p0:0.991, p1:1.000, r0:1.000, r1:0.931, f1:0.964.
# Test ACC | p0:0.982, p1:1.000, r0:1.000, r1:0.867, f1:0.929.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/143XB8CT_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_143XB8CT_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_143XB8CT_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_143XB8CT_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.02494693 0.97505307]
# Traceback (most recent call last):
#   File "train.py", line 157, in <module>
#     trainer.train()
#   File "../semi_supervised_AD/trainer/tgconv_ngat_cluster_trainer2.py", line 141, in train
#     unsup_node_emb, unsup_graph_emb, unsup_out = self.model(unsup_data)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "../semi_supervised_AD/models/tgconv_ngat.py", line 112, in forward
#     node_emb = self.embed_node(input_data)
#   File "../semi_supervised_AD/models/tgconv_ngat.py", line 74, in embed_node
#     node_emb = self.encoder(x, batch=input_data.batch,
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "../semi_supervised_AD/models/tgconv_ngat_base.py", line 74, in forward
#     out_0_i = self._graph_conv(out_0_i, edge_index, edge_weight)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/gat_conv.py", line 152, in forward
#     out = self.propagate(edge_index, x=(x_l, x_r),
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/message_passing.py", line 237, in propagate
#     out = self.message(**msg_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/nn/conv/gat_conv.py", line 180, in message
#     alpha = softmax(alpha, index, ptr, size_i)
# RuntimeError: The following operation failed in the TorchScript interpreter.
# Traceback of TorchScript (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch_geometric/utils/softmax.py", line 42, in softmax
#         N = maybe_num_nodes(index, num_nodes)
#         src_max = scatter(src, index, dim, dim_size=N, reduce='max')
#         src_max = src_max.index_select(dim, index)
#                   ~~~~~~~~~~~~~~~~~~~~ <--- HERE
#         out = (src - src_max).exp()
#         out_sum = scatter(out, index, dim, dim_size=N, reduce='sum')
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 1; 11.91 GiB total capacity; 10.33 GiB already allocated; 17.56 MiB free; 10.53 GiB reserved in total by PyTorch)
#
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT30990_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT30990_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT30990_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT30990_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.02130998 0.97869002]
# [[ 1.6939495  -0.02222529  1.300274    0.01258929 -0.9255819 ]
#  [-0.6357506  -0.7558526   0.40228474 -0.29974172 -0.7671845 ]]
# Epoch: 0 / 100 | Train Time: 85.273 | Train Loss: 0.118718; Center Loss: 0.027128; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.118718;
# Val ACC | p0:0.979, p1:0.667, r0:0.023, r1:0.357, f1:0.043.
# Test ACC | p0:0.981, p1:0.719, r0:0.032, r1:0.400, f1:0.059.
# >>> Models have been saved.
# -24.269857 43.272167
# 58.075375 -10.898427
# -24.269857 43.272167
# 58.075375 -10.898427
# [[ 1.6939657  -0.02222017  1.3002812   0.01259049 -0.9255831 ]
#  [-0.63577557 -0.7558563   0.4022727  -0.29974082 -0.76718193]]
# Epoch: 1 / 100 | Train Time: 83.173 | Train Loss: 0.153091; Center Loss: 0.024677; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.153091;
# Val ACC | p0:0.984, p1:0.932, r0:0.083, r1:0.286, f1:0.129.
# Test ACC | p0:0.982, p1:0.949, r0:0.108, r1:0.267, f1:0.154.
# >>> Models have been saved.
# 1.0387734 54.793026
# 20.106443 52.9863
# 1.0387734 54.793026
# 20.106443 52.9863
# [[ 1.6939687  -0.02221467  1.3002843   0.01259623 -0.92558306]
#  [-0.63577515 -0.75586027  0.4022698  -0.29974526 -0.76717955]]
# Epoch: 2 / 100 | Train Time: 83.181 | Train Loss: 0.093255; Center Loss: 0.009258; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.093255;
# Val ACC | p0:0.982, p1:0.921, r0:0.056, r1:0.214, f1:0.088.
# Test ACC | p0:0.984, p1:0.957, r0:0.152, r1:0.333, f1:0.208.
# [[ 1.693971   -0.02221439  1.3002853   0.0125967  -0.92558306]
#  [-0.6357756  -0.7558602   0.40226775 -0.2997462  -0.7671781 ]]
# Epoch: 3 / 100 | Train Time: 85.321 | Train Loss: 0.060922; Center Loss: 0.006220; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.060922;
# Val ACC | p0:0.985, p1:0.936, r0:0.109, r1:0.357, f1:0.167.
# Test ACC | p0:0.984, p1:0.957, r0:0.152, r1:0.333, f1:0.208.
# >>> Models have been saved.
# -4.804035 -10.424483
# -0.23503019 17.561441
# -4.804035 -10.424483
# -0.23503019 17.561441
# [[ 1.6939737  -0.02221268  1.3002867   0.01259726 -0.92558396]
#  [-0.6357757  -0.7558607   0.4022665  -0.29974687 -0.76717836]]
# Epoch: 4 / 100 | Train Time: 84.442 | Train Loss: 0.044851; Center Loss: 0.004296; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.044851;
# Val ACC | p0:0.984, p1:0.986, r0:0.308, r1:0.286, f1:0.296.
# Test ACC | p0:0.983, p1:0.988, r0:0.333, r1:0.267, f1:0.296.
# >>> Models have been saved.
# 14.317268 -35.64804
# 36.45983 -27.948801
# 14.317268 -35.64804
# 36.45983 -27.948801
# [[ 1.6939762  -0.02221247  1.3002871   0.01259755 -0.92558384]
#  [-0.6357779  -0.755861    0.40226495 -0.29974675 -0.7671774 ]]
# Epoch: 5 / 100 | Train Time: 82.535 | Train Loss: 0.052046; Center Loss: 0.004777; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.052046;
# Val ACC | p0:0.986, p1:0.967, r0:0.192, r1:0.357, f1:0.250.
# Test ACC | p0:0.984, p1:0.981, r0:0.294, r1:0.333, f1:0.312.
# [[ 1.6939782  -0.02221074  1.3002877   0.01259941 -0.9255835 ]
#  [-0.6357813  -0.7558607   0.40226293 -0.2997464  -0.7671762 ]]
# Epoch: 6 / 100 | Train Time: 80.386 | Train Loss: 0.043089; Center Loss: 0.004092; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.043089;
# Val ACC | p0:0.986, p1:0.988, r0:0.385, r1:0.357, f1:0.370.
# Test ACC | p0:0.983, p1:0.992, r0:0.444, r1:0.267, f1:0.333.
# >>> Models have been saved.
# -38.346367 27.781456
# -2.8997707 16.871254
# -38.346367 27.781456
# -2.8997707 16.871254
# [[ 1.6939813  -0.02221059  1.3002898   0.01259866 -0.9255845 ]
#  [-0.6357831  -0.755861    0.40226173 -0.29974672 -0.76717603]]
# Epoch: 7 / 100 | Train Time: 84.406 | Train Loss: 0.038595; Center Loss: 0.003551; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.038595;
# Val ACC | p0:0.984, p1:0.932, r0:0.083, r1:0.286, f1:0.129.
# Test ACC | p0:0.985, p1:0.938, r0:0.130, r1:0.400, f1:0.197.
# [[ 1.6939864  -0.02220997  1.3002918   0.01259901 -0.925585  ]
#  [-0.63578665 -0.75586104  0.40225962 -0.299747   -0.7671748 ]]
# Epoch: 8 / 100 | Train Time: 85.116 | Train Loss: 0.050757; Center Loss: 0.004778; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.050757;
# Val ACC | p0:0.984, p1:0.974, r0:0.190, r1:0.286, f1:0.229.
# Test ACC | p0:0.984, p1:0.980, r0:0.278, r1:0.333, f1:0.303.
# [[ 1.6939888  -0.02220884  1.3002938   0.01259968 -0.9255847 ]
#  [-0.6357885  -0.7558616   0.40225795 -0.29974672 -0.7671745 ]]
# Epoch: 9 / 100 | Train Time: 85.416 | Train Loss: 0.043893; Center Loss: 0.004121; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.043893;
# Val ACC | p0:0.986, p1:0.967, r0:0.192, r1:0.357, f1:0.250.
# Test ACC | p0:0.986, p1:0.983, r0:0.353, r1:0.400, f1:0.375.
# [[ 1.6939889  -0.02220766  1.3002955   0.01260016 -0.9255857 ]
#  [-0.6357915  -0.7558627   0.402255   -0.29974663 -0.76717275]]
# Epoch: 10 / 100 | Train Time: 85.265 | Train Loss: 0.035743; Center Loss: 0.003169; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.035743;
# Val ACC | p0:0.986, p1:0.980, r0:0.278, r1:0.357, f1:0.313.
# Test ACC | p0:0.984, p1:0.980, r0:0.278, r1:0.333, f1:0.303.
# [[ 1.6939925  -0.02220754  1.3002954   0.01260012 -0.9255866 ]
#  [-0.6357949  -0.755861    0.4022548  -0.29974604 -0.76717263]]
# Epoch: 11 / 100 | Train Time: 85.431 | Train Loss: 0.036197; Center Loss: 0.003377; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.036197;
# Val ACC | p0:0.986, p1:0.986, r0:0.357, r1:0.357, f1:0.357.
# Test ACC | p0:0.985, p1:0.991, r0:0.455, r1:0.333, f1:0.385.
# [[ 1.693995   -0.02220656  1.3002957   0.01260129 -0.92558545]
#  [-0.63579774 -0.75586194  0.4022534  -0.29974636 -0.76717234]]
# Epoch: 12 / 100 | Train Time: 84.821 | Train Loss: 0.034470; Center Loss: 0.003189; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.034470;
# Val ACC | p0:0.986, p1:0.983, r0:0.312, r1:0.357, f1:0.333.
# Test ACC | p0:0.985, p1:0.989, r0:0.417, r1:0.333, f1:0.370.
# [[ 1.6939983  -0.02220587  1.3002979   0.0126018  -0.92558664]
#  [-0.63579935 -0.75586253  0.4022526  -0.29974693 -0.76717156]]
# Epoch: 13 / 100 | Train Time: 83.067 | Train Loss: 0.032233; Center Loss: 0.003088; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.032233;
# Val ACC | p0:0.986, p1:0.989, r0:0.417, r1:0.357, f1:0.385.
# Test ACC | p0:0.985, p1:0.992, r0:0.500, r1:0.333, f1:0.400.
# >>> Models have been saved.
# -10.340844 -41.471325
# 2.1593041 -1.158943
# -10.340844 -41.471325
# 2.1593041 -1.158943
# [[ 1.6940006  -0.0222053   1.3002996   0.012602   -0.9255865 ]
#  [-0.6358021  -0.7558629   0.40225142 -0.29974693 -0.767171  ]]
# Epoch: 14 / 100 | Train Time: 83.852 | Train Loss: 0.035267; Center Loss: 0.003303; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.035267;
# Val ACC | p0:0.986, p1:0.988, r0:0.385, r1:0.357, f1:0.370.
# Test ACC | p0:0.985, p1:0.992, r0:0.500, r1:0.333, f1:0.400.
# [[ 1.694003   -0.02220571  1.3002989   0.0126019  -0.9255857 ]
#  [-0.63580406 -0.75586104  0.40224957 -0.299746   -0.76716954]]
# Epoch: 15 / 100 | Train Time: 84.206 | Train Loss: 0.082599; Center Loss: 0.007763; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.082599;
# Val ACC | p0:0.983, p1:0.921, r0:0.073, r1:0.286, f1:0.116.
# Test ACC | p0:0.984, p1:0.958, r0:0.156, r1:0.333, f1:0.213.
# [[ 1.6940014  -0.02220517  1.3003012   0.0126024  -0.92558575]
#  [-0.63579744 -0.7558615   0.4022492  -0.29974586 -0.7671699 ]]
# Epoch: 16 / 100 | Train Time: 85.183 | Train Loss: 0.072002; Center Loss: 0.007811; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.072002;
# Val ACC | p0:0.986, p1:0.966, r0:0.185, r1:0.357, f1:0.244.
# Test ACC | p0:0.984, p1:0.974, r0:0.227, r1:0.333, f1:0.270.
# [[ 1.6940007  -0.02220322  1.3003023   0.01260352 -0.9255864 ]
#  [-0.6357991  -0.75586224  0.40224722 -0.2997461  -0.76716924]]
# Epoch: 17 / 100 | Train Time: 85.100 | Train Loss: 0.061492; Center Loss: 0.006890; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.061492;
# Val ACC | p0:0.986, p1:0.984, r0:0.333, r1:0.357, f1:0.345.
# Test ACC | p0:0.983, p1:0.991, r0:0.400, r1:0.267, f1:0.320.
# [[ 1.694      -0.022203    1.3003027   0.01260367 -0.9255864 ]
#  [-0.6357979  -0.7558623   0.40224615 -0.29974616 -0.7671687 ]]
# Epoch: 18 / 100 | Train Time: 82.520 | Train Loss: 0.053612; Center Loss: 0.006129; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.053612;
# Val ACC | p0:0.986, p1:0.960, r0:0.161, r1:0.357, f1:0.222.
# Test ACC | p0:0.983, p1:0.964, r0:0.148, r1:0.267, f1:0.190.
# [[ 1.6940004  -0.02220262  1.3003019   0.0126038  -0.92558604]
#  [-0.6358005  -0.7558629   0.4022447  -0.2997462  -0.7671685 ]]
# Epoch: 19 / 100 | Train Time: 85.803 | Train Loss: 0.051051; Center Loss: 0.005429; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.051051;
# Val ACC | p0:0.985, p1:0.942, r0:0.119, r1:0.357, f1:0.179.
# Test ACC | p0:0.982, p1:0.957, r0:0.125, r1:0.267, f1:0.170.
# [[ 1.6940022  -0.02220144  1.3003021   0.01260431 -0.9255865 ]
#  [-0.63580227 -0.75586236  0.40224445 -0.299746   -0.7671681 ]]
# Epoch: 20 / 100 | Train Time: 84.730 | Train Loss: 0.050817; Center Loss: 0.004891; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.050817;
# Val ACC | p0:0.986, p1:0.963, r0:0.172, r1:0.357, f1:0.233.
# Test ACC | p0:0.986, p1:0.978, r0:0.300, r1:0.400, f1:0.343.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT48337_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT48337_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT48337_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT48337_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.0479004 0.9520996]
# [[ 0.01800493 -0.3524825   0.39370203 -0.00700213 -0.44501108]
#  [-0.42186123 -0.359189    1.0310037  -1.3999323  -0.53658175]]
# Epoch: 0 / 100 | Train Time: 223.655 | Train Loss: 0.139172; Center Loss: 0.068986; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.139172;
# Val ACC | p0:0.970, p1:0.911, r0:0.194, r1:0.438, f1:0.269.
# Test ACC | p0:0.971, p1:0.914, r0:0.243, r1:0.500, f1:0.327.
# >>> Models have been saved.
# 29.923212 7.910913
# 20.809706 -38.723274
# 29.923212 7.910913
# 20.809706 -38.723274
# [[ 0.01800775 -0.35248214  0.39369854 -0.00699265 -0.4450075 ]
#  [-0.42186326 -0.3591874   1.031005   -1.3999403  -0.5365818 ]]
# Epoch: 1 / 100 | Train Time: 223.289 | Train Loss: 0.119730; Center Loss: 0.054867; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.119730;
# Val ACC | p0:0.987, p1:0.935, r0:0.364, r1:0.750, f1:0.490.
# Test ACC | p0:0.975, p1:0.942, r0:0.345, r1:0.556, f1:0.426.
# >>> Models have been saved.
# 30.36874 41.92401
# -48.081192 -16.670519
# 30.36874 41.92401
# -48.081192 -16.670519
# [[ 0.01801074 -0.35248086  0.39369553 -0.00698549 -0.44500583]
#  [-0.42186528 -0.35918713  1.031005   -1.3999453  -0.53658175]]
# Epoch: 2 / 100 | Train Time: 224.353 | Train Loss: 0.104487; Center Loss: 0.055769; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.104487;
# Val ACC | p0:0.987, p1:0.954, r0:0.444, r1:0.750, f1:0.558.
# Test ACC | p0:0.978, p1:0.969, r0:0.524, r1:0.611, f1:0.564.
# >>> Models have been saved.
# 83.59628 66.70225
# -5.5495086 -27.938406
# 83.59628 66.70225
# -5.5495086 -27.938406
# [[ 0.01800474 -0.35248372  0.39369214 -0.00698189 -0.4450104 ]
#  [-0.4218544  -0.3591812   1.0310037  -1.399945   -0.536572  ]]
# Epoch: 3 / 100 | Train Time: 223.548 | Train Loss: 0.122992; Center Loss: 0.045472; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.122992;
# Val ACC | p0:0.986, p1:0.868, r0:0.218, r1:0.750, f1:0.338.
# Test ACC | p0:0.971, p1:0.829, r0:0.152, r1:0.556, f1:0.238.
# [[ 0.01800557 -0.35248306  0.39369038 -0.00697968 -0.44500887]
#  [-0.42185485 -0.3591812   1.0310037  -1.3999456  -0.536572  ]]
# Epoch: 4 / 100 | Train Time: 224.710 | Train Loss: 0.091905; Center Loss: 0.015295; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.091905;
# Val ACC | p0:0.986, p1:0.898, r0:0.267, r1:0.750, f1:0.393.
# Test ACC | p0:0.979, p1:0.859, r0:0.207, r1:0.667, f1:0.316.
# [[ 0.01799268 -0.35249272  0.39369273 -0.00698883 -0.44502324]
#  [-0.4218452  -0.35917446  1.0309994  -1.3999362  -0.53656125]]
# Epoch: 5 / 100 | Train Time: 224.963 | Train Loss: 0.112900; Center Loss: 0.021566; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.112900;
# Val ACC | p0:0.981, p1:0.935, r0:0.323, r1:0.625, f1:0.426.
# Test ACC | p0:0.967, p1:0.890, r0:0.182, r1:0.444, f1:0.258.
# [[ 0.01799705 -0.35249218  0.3936851  -0.00697354 -0.44502378]
#  [-0.42185268 -0.35916954  1.0310088  -1.399949   -0.5365636 ]]
# Epoch: 6 / 100 | Train Time: 225.566 | Train Loss: 0.153931; Center Loss: 0.030785; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.153931;
# Val ACC | p0:0.990, p1:0.917, r0:0.325, r1:0.812, f1:0.464.
# Test ACC | p0:0.974, p1:0.908, r0:0.250, r1:0.556, f1:0.345.
# [[ 0.01799931 -0.35249108  0.39368555 -0.00696179 -0.44503418]
#  [-0.4218506  -0.3591689   1.0309983  -1.3999509  -0.53655034]]
# Epoch: 7 / 100 | Train Time: 224.125 | Train Loss: 0.123020; Center Loss: 0.035466; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.123020;
# Val ACC | p0:0.987, p1:0.932, r0:0.353, r1:0.750, f1:0.480.
# Test ACC | p0:0.974, p1:0.920, r0:0.278, r1:0.556, f1:0.370.
# [[ 0.01799886 -0.35248795  0.39368653 -0.00695919 -0.44503602]
#  [-0.42185012 -0.35916704  1.0309995  -1.3999524  -0.53654844]]
# Epoch: 8 / 100 | Train Time: 224.732 | Train Loss: 0.102812; Center Loss: 0.034475; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.102812;
# Val ACC | p0:0.990, p1:0.954, r0:0.464, r1:0.812, f1:0.591.
# Test ACC | p0:0.984, p1:0.945, r0:0.419, r1:0.722, f1:0.531.
# >>> Models have been saved.
# -6.3398604 -36.85932
# -45.41311 4.354474
# -6.3398604 -36.85932
# -45.41311 4.354474
# [[ 0.01799737 -0.35249165  0.3936824  -0.00695642 -0.4450373 ]
#  [-0.4218489  -0.35916555  1.030999   -1.3999515  -0.53654796]]
# Epoch: 9 / 100 | Train Time: 225.637 | Train Loss: 0.094569; Center Loss: 0.038618; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.094569;
# Val ACC | p0:0.987, p1:0.969, r0:0.545, r1:0.750, f1:0.632.
# Test ACC | p0:0.987, p1:0.957, r0:0.500, r1:0.778, f1:0.609.
# >>> Models have been saved.
# 14.856094 -8.078226
# 22.562544 -11.695834
# 14.856094 -8.078226
# 22.562544 -11.695834
# [[ 0.01799785 -0.35249183  0.39368096 -0.00695096 -0.44503736]
#  [-0.42184952 -0.3591646   1.0309987  -1.3999524  -0.5365475 ]]
# Epoch: 10 / 100 | Train Time: 225.031 | Train Loss: 0.087496; Center Loss: 0.049021; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.087496;
# Val ACC | p0:0.988, p1:0.972, r0:0.571, r1:0.750, f1:0.649.
# Test ACC | p0:0.984, p1:0.969, r0:0.565, r1:0.722, f1:0.634.
# >>> Models have been saved.
# 10.70195 -14.596755
# 19.038042 -28.097137
# 10.70195 -14.596755
# 19.038042 -28.097137
# [[ 0.01799963 -0.3524914   0.39367795 -0.00694823 -0.445036  ]
#  [-0.42185146 -0.35916504  1.0310001  -1.3999575  -0.536548  ]]
# Epoch: 11 / 100 | Train Time: 224.512 | Train Loss: 0.084033; Center Loss: 0.075715; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.084033;
# Val ACC | p0:0.988, p1:0.978, r0:0.632, r1:0.750, f1:0.686.
# Test ACC | p0:0.981, p1:0.963, r0:0.500, r1:0.667, f1:0.571.
# >>> Models have been saved.
# 27.996723 -30.983816
# 46.972065 -4.208451
# 27.996723 -30.983816
# 46.972065 -4.208451
# [[ 0.0180007  -0.35248977  0.39367703 -0.00694558 -0.44503477]
#  [-0.4218529  -0.35916558  1.0310006  -1.3999631  -0.536549  ]]
# Epoch: 12 / 100 | Train Time: 223.034 | Train Loss: 0.075814; Center Loss: 0.088618; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.075814;
# Val ACC | p0:0.988, p1:0.982, r0:0.667, r1:0.750, f1:0.706.
# Test ACC | p0:0.985, p1:0.979, r0:0.650, r1:0.722, f1:0.684.
# >>> Models have been saved.
# -35.135384 10.270344
# -40.164577 -32.185097
# -35.135384 10.270344
# -40.164577 -32.185097
# [[ 0.01800046 -0.35248896  0.39367676 -0.00694367 -0.4450344 ]
#  [-0.4218533  -0.35916588  1.0310022  -1.3999677  -0.5365488 ]]
# Epoch: 13 / 100 | Train Time: 225.152 | Train Loss: 0.072186; Center Loss: 0.091662; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.072186;
# Val ACC | p0:0.988, p1:0.975, r0:0.600, r1:0.750, f1:0.667.
# Test ACC | p0:0.988, p1:0.969, r0:0.583, r1:0.778, f1:0.667.
# [[ 0.01800045 -0.35248762  0.39367607 -0.00694169 -0.44503304]
#  [-0.42185315 -0.35916638  1.0310022  -1.399969   -0.53654915]]
# Epoch: 14 / 100 | Train Time: 222.151 | Train Loss: 0.067412; Center Loss: 0.098245; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.067412;
# Val ACC | p0:0.988, p1:0.982, r0:0.667, r1:0.750, f1:0.706.
# Test ACC | p0:0.988, p1:0.969, r0:0.583, r1:0.778, f1:0.667.
# [[ 0.01799968 -0.35248622  0.39367592 -0.0069391  -0.44503203]
#  [-0.42185238 -0.35916778  1.0310038  -1.3999702  -0.5365501 ]]
# Epoch: 15 / 100 | Train Time: 221.998 | Train Loss: 0.065346; Center Loss: 0.113595; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.065346;
# Val ACC | p0:0.985, p1:0.985, r0:0.688, r1:0.688, f1:0.688.
# Test ACC | p0:0.985, p1:0.988, r0:0.765, r1:0.722, f1:0.743.
# [[ 0.01799953 -0.35248518  0.393676   -0.00693788 -0.44503075]
#  [-0.42185202 -0.35916883  1.0310031  -1.39997    -0.5365516 ]]
# Epoch: 16 / 100 | Train Time: 222.017 | Train Loss: 0.062878; Center Loss: 0.110563; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.062878;
# Val ACC | p0:0.988, p1:0.988, r0:0.750, r1:0.750, f1:0.750.
# Test ACC | p0:0.988, p1:0.988, r0:0.778, r1:0.778, f1:0.778.
# >>> Models have been saved.
# -6.031039 36.031914
# ...
# Epoch: 20 / 100 | Train Time: 221.520 | Train Loss: 0.071305; Center Loss: 0.064495; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.071305;
# Val ACC | p0:0.991, p1:0.988, r0:0.765, r1:0.812, f1:0.788.
# Test ACC | p0:0.982, p1:0.979, r0:0.632, r1:0.667, f1:0.649.
# [[ 0.01799739 -0.35248291  0.3936771  -0.00693934 -0.44502926]
#  [-0.42185053 -0.35917157  1.0310014  -1.3999748  -0.5365543 ]]
# Epoch: 21 / 100 | Train Time: 222.298 | Train Loss: 0.066192; Center Loss: 0.072478; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.066192;
# Val ACC | p0:0.994, p1:1.000, r0:1.000, r1:0.875, f1:0.933.
# Test ACC | p0:0.985, p1:0.997, r0:0.929, r1:0.722, f1:0.813.
# >>> Models have been saved.
# 80.238716 64.452965
# -4.540949 -65.42851
# 80.238716 64.452965
# -4.540949 -65.42851
# [[ 0.01799629 -0.35248196  0.39367807 -0.00694009 -0.44502804]
#  [-0.42184946 -0.3591731   1.031      -1.3999726  -0.536555  ]]
# Epoch: 22 / 100 | Train Time: 221.817 | Train Loss: 0.063028; Center Loss: 0.074564; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.063028;
# Val ACC | p0:0.994, p1:0.994, r0:0.875, r1:0.875, f1:0.875.
# Test ACC | p0:0.985, p1:0.994, r0:0.867, r1:0.722, f1:0.788.
# [[ 0.01799496 -0.35247993  0.39367878 -0.00693986 -0.44502607]
#  [-0.42184904 -0.35917425  1.0310004  -1.399975   -0.53655523]]
# Epoch: 23 / 100 | Train Time: 223.544 | Train Loss: 0.070636; Center Loss: 0.070651; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.070636;
# Val ACC | p0:0.988, p1:0.991, r0:0.800, r1:0.750, f1:0.774.
# Test ACC | p0:0.982, p1:0.991, r0:0.800, r1:0.667, f1:0.727.
# [[ 0.01799126 -0.35247788  0.39368337 -0.00694176 -0.44502363]
#  [-0.4218471  -0.35917625  1.0309983  -1.3999764  -0.53655696]]
# Epoch: 24 / 100 | Train Time: 221.746 | Train Loss: 0.068940; Center Loss: 0.061351; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.068940;
# Val ACC | p0:0.991, p1:0.988, r0:0.765, r1:0.812, f1:0.788.
# Test ACC | p0:0.985, p1:0.994, r0:0.867, r1:0.722, f1:0.788.
# [[ 0.01798846 -0.35247323  0.39368355 -0.0069422  -0.44501972]
#  [-0.421844   -0.35918015  1.0309976  -1.3999778  -0.53656024]]
# Epoch: 25 / 100 | Train Time: 220.686 | Train Loss: 0.061541; Center Loss: 0.054806; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.061541;
# Val ACC | p0:0.994, p1:0.985, r0:0.737, r1:0.875, f1:0.800.
# Test ACC | p0:0.985, p1:0.982, r0:0.684, r1:0.722, f1:0.703.
# [[ 0.0179784  -0.3524595   0.3936889  -0.00693934 -0.4450069 ]
#  [-0.42183337 -0.35919383  1.0309939  -1.3999802  -0.5365734 ]]
# Epoch: 26 / 100 | Train Time: 221.571 | Train Loss: 0.051370; Center Loss: 0.020494; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.051370;
# Val ACC | p0:0.990, p1:0.920, r0:0.333, r1:0.812, f1:0.473.
# Test ACC | p0:0.984, p1:0.933, r0:0.371, r1:0.722, f1:0.491.
# [[ 0.01797832 -0.3524616   0.3936877  -0.00693546 -0.44500947]
#  [-0.421833   -0.35919297  1.0309924  -1.3999808  -0.5365725 ]]
# Epoch: 27 / 100 | Train Time: 220.250 | Train Loss: 0.048881; Center Loss: 0.004415; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.048881;
# Val ACC | p0:0.994, p1:0.966, r0:0.560, r1:0.875, f1:0.683.
# Test ACC | p0:0.990, p1:0.945, r0:0.455, r1:0.833, f1:0.588.
# [[ 0.01797903 -0.3524604   0.39368722 -0.00693786 -0.44500753]
#  [-0.42183363 -0.35919365  1.0309924  -1.3999771  -0.5365729 ]]
# Epoch: 28 / 100 | Train Time: 218.297 | Train Loss: 0.076608; Center Loss: 0.022905; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.076608;
# Val ACC | p0:0.984, p1:0.960, r0:0.458, r1:0.688, f1:0.550.
# Test ACC | p0:0.981, p1:0.972, r0:0.571, r1:0.667, f1:0.615.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT19213_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT19213_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT19213_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 8
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT19213_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.03703869 0.96296131]
# [[-1.6088375  -0.4067319   1.3159368   0.30133727 -0.00172952]
#  [ 0.57977355  1.6049627  -0.69351554 -0.17752849 -0.16522047]]
# Epoch: 0 / 100 | Train Time: 485.722 | Train Loss: 0.104572; Center Loss: 0.086841; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.104572;
# Val ACC | p0:0.972, p1:0.704, r0:0.056, r1:0.467, f1:0.100.
# Test ACC | p0:0.984, p1:0.761, r0:0.111, r1:0.706, f1:0.192.
# >>> Models have been saved.
# 20.41807 24.545063
# 20.85938 -43.884296
# 20.41807 24.545063
# 20.85938 -43.884296
# [[-1.6088213  -0.4067367   1.3159261   0.30134565 -0.00171414]
#  [ 0.57979137  1.6049746  -0.6935287  -0.17754498 -0.16524045]]
# Epoch: 1 / 100 | Train Time: 484.383 | Train Loss: 0.144147; Center Loss: 0.360024; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.144147;
# Val ACC | p0:0.973, p1:0.712, r0:0.057, r1:0.467, f1:0.102.
# Test ACC | p0:0.981, p1:0.758, r0:0.102, r1:0.647, f1:0.176.
# >>> Models have been saved.
# -1.8724626 -23.099163
# -0.9186589 -23.283388
# -1.8724626 -23.099163
# -0.9186589 -23.283388
# [[-1.6088445  -0.40675166  1.31594     0.30134767 -0.00171203]
#  [ 0.5798174   1.6049953  -0.6935497  -0.17755234 -0.16524293]]
# Epoch: 2 / 100 | Train Time: 487.886 | Train Loss: 0.075382; Center Loss: 0.060385; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.075382;
# Val ACC | p0:1.000, p1:0.115, r0:0.041, r1:1.000, f1:0.078.
# Test ACC | p0:1.000, p1:0.150, r0:0.047, r1:1.000, f1:0.091.
# [[-1.6088479  -0.4067602   1.3159411   0.3013468  -0.00171096]
#  [ 0.57982504  1.6050007  -0.69355595 -0.17755374 -0.16524392]]
# Epoch: 3 / 100 | Train Time: 487.682 | Train Loss: 0.069676; Center Loss: 0.046148; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.069676;
# Val ACC | p0:0.973, p1:0.722, r0:0.059, r1:0.467, f1:0.105.
# Test ACC | p0:0.981, p1:0.761, r0:0.103, r1:0.647, f1:0.177.
# >>> Models have been saved.
# 4.4616523 -12.085235
# -91.709984 38.658493
# 4.4616523 -12.085235
# -91.709984 38.658493
# [[-1.6088458  -0.4067649   1.3159378   0.30134657 -0.00170908]
#  [ 0.5798309   1.6050034  -0.6935619  -0.17755531 -0.16524407]]
# Epoch: 4 / 100 | Train Time: 491.508 | Train Loss: 0.069056; Center Loss: 0.045757; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.069056;
# Val ACC | p0:0.979, p1:0.115, r0:0.038, r1:0.933, f1:0.073.
# Test ACC | p0:1.000, p1:0.150, r0:0.047, r1:1.000, f1:0.091.
# [[-1.6088442  -0.40676537  1.3159362   0.30134678 -0.00170912]
#  [ 0.5798323   1.6050068  -0.69356316 -0.17755556 -0.16524398]]
# Epoch: 5 / 100 | Train Time: 486.028 | Train Loss: 0.070028; Center Loss: 0.043545; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.070028;
# Val ACC | p0:0.968, p1:0.687, r0:0.046, r1:0.400, f1:0.082.
# Test ACC | p0:0.980, p1:0.716, r0:0.088, r1:0.647, f1:0.155.
# [[-1.6088376  -0.40677345  1.3159376   0.30134603 -0.0017084 ]
#  [ 0.57984334  1.6050166  -0.6935734  -0.1775578  -0.16524436]]
# Epoch: 6 / 100 | Train Time: 490.222 | Train Loss: 0.071129; Center Loss: 0.045001; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.071129;
# Val ACC | p0:0.976, p1:0.617, r0:0.056, r1:0.600, f1:0.102.
# Test ACC | p0:0.967, p1:0.576, r0:0.050, r1:0.529, f1:0.092.
# [[-1.6088337  -0.40677395  1.3159345   0.30134496 -0.00170792]
#  [ 0.5798479   1.6050155  -0.69357747 -0.17755905 -0.165244  ]]
# Epoch: 7 / 100 | Train Time: 489.125 | Train Loss: 0.070462; Center Loss: 0.043322; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.070462;
# Val ACC | p0:0.973, p1:0.551, r0:0.048, r1:0.600, f1:0.089.
# Test ACC | p0:0.958, p1:0.574, r0:0.039, r1:0.412, f1:0.072.
# [[-1.6088381  -0.40678018  1.3159374   0.30134693 -0.00170701]
#  [ 0.5798553   1.6050212  -0.6935841  -0.17756066 -0.16524373]]
# Epoch: 8 / 100 | Train Time: 485.278 | Train Loss: 0.070249; Center Loss: 0.043574; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.070249;
# Val ACC | p0:0.960, p1:0.774, r0:0.022, r1:0.133, f1:0.037.
# Test ACC | p0:0.951, p1:0.733, r0:0.018, r1:0.118, f1:0.032.
# [[-1.6088368  -0.40678307  1.3159353   0.30134657 -0.00170617]
#  [ 0.5798601   1.6050235  -0.6935885  -0.177562   -0.16524391]]
# Epoch: 9 / 100 | Train Time: 484.571 | Train Loss: 0.070006; Center Loss: 0.042649; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.070006;
# Val ACC | p0:0.962, p1:0.511, r0:0.035, r1:0.467, f1:0.065.
# Test ACC | p0:0.955, p1:0.476, r0:0.037, r1:0.471, f1:0.068.
# [[-1.608837   -0.4067881   1.3159364   0.30134755 -0.00170608]
#  [ 0.57986474  1.6050265  -0.6935931  -0.17756322 -0.16524403]]
# Epoch: 10 / 100 | Train Time: 487.238 | Train Loss: 0.070376; Center Loss: 0.043521; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.070376;
# Val ACC | p0:0.970, p1:0.479, r0:0.041, r1:0.600, f1:0.078.
# Test ACC | p0:0.955, p1:0.529, r0:0.036, r1:0.412, f1:0.066.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT22885_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT22885_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT22885_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 32
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT22885_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.05336194 0.94663806]
# [[-0.5592464  -0.2393832  -0.09043466 -1.3468188  -1.6206939 ]
#  [ 1.2444972   1.6723367   0.59018016  0.8447385  -0.54259485]]
# Epoch: 0 / 100 | Train Time: 229.416 | Train Loss: 0.142740; Center Loss: 0.039398; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.142740;
# Val ACC | p0:0.979, p1:0.722, r0:0.127, r1:0.722, f1:0.217.
# Test ACC | p0:0.991, p1:0.688, r0:0.145, r1:0.895, f1:0.250.
# >>> Models have been saved.
# 18.78517 33.311436
# -2.3094833 31.60575
# 18.78517 33.311436
# -2.3094833 31.60575
# [[-0.55924654 -0.23940001 -0.0904225  -1.346817   -1.6206864 ]
#  [ 1.2444986   1.6723586   0.5901676   0.84473914 -0.54259896]]
# Epoch: 1 / 100 | Train Time: 227.250 | Train Loss: 0.220052; Center Loss: 0.109651; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.220052;
# Val ACC | p0:0.962, p1:0.800, r0:0.111, r1:0.444, f1:0.178.
# Test ACC | p0:0.977, p1:0.794, r0:0.165, r1:0.684, f1:0.265.
# [[-0.5592848  -0.23944701 -0.09043134 -1.3468626  -1.6207141 ]
#  [ 1.2445408   1.6724079   0.59017724  0.8447877  -0.5425691 ]]
# Epoch: 2 / 100 | Train Time: 229.810 | Train Loss: 0.174353; Center Loss: 0.051245; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.174353;
# Val ACC | p0:0.971, p1:0.838, r0:0.161, r1:0.556, f1:0.250.
# Test ACC | p0:0.951, p1:0.847, r0:0.093, r1:0.263, f1:0.137.
# >>> Models have been saved.
# 7.535685 -30.150833
# 7.2870846 30.637745
# 7.535685 -30.150833
# 7.2870846 30.637745
# [[-0.5593333  -0.23950526 -0.09045486 -1.3469241  -1.6207511 ]
#  [ 1.2445922   1.6724672   0.59020245  0.8448521  -0.5425324 ]]
# Epoch: 3 / 100 | Train Time: 231.733 | Train Loss: 0.168471; Center Loss: 0.039968; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.168471;
# Val ACC | p0:0.980, p1:0.897, r0:0.267, r1:0.667, f1:0.381.
# Test ACC | p0:0.987, p1:0.913, r0:0.349, r1:0.789, f1:0.484.
# >>> Models have been saved.
# 31.008455 -0.11542342
# 24.750872 20.543077
# 31.008455 -0.11542342
# 24.750872 20.543077
# [[-0.55935806 -0.23953228 -0.09046163 -1.3469565  -1.620769  ]
#  [ 1.244615    1.6724929   0.5902078   0.8448834  -0.5425145 ]]
# Epoch: 4 / 100 | Train Time: 225.835 | Train Loss: 0.116379; Center Loss: 0.017498; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.116379;
# Val ACC | p0:0.975, p1:0.956, r0:0.417, r1:0.556, f1:0.476.
# Test ACC | p0:0.984, p1:0.947, r0:0.452, r1:0.737, f1:0.560.
# >>> Models have been saved.
# 35.176662 -22.528027
# 34.15216 -7.3381624
# 35.176662 -22.528027
# 34.15216 -7.3381624
# [[-0.5593709  -0.23954588 -0.0904683  -1.3469741  -1.6207786 ]
#  [ 1.2446299   1.6725055   0.590215    0.84490204 -0.5425039 ]]
# Epoch: 5 / 100 | Train Time: 225.285 | Train Loss: 0.096583; Center Loss: 0.029594; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.096583;
# Val ACC | p0:0.978, p1:0.978, r0:0.611, r1:0.611, f1:0.611.
# Test ACC | p0:0.994, p1:0.988, r0:0.810, r1:0.895, f1:0.850.
# >>> Models have been saved.
# 27.694674 13.232228
# 24.514738 62.126663
# 27.694674 13.232228
# 24.514738 62.126663
# Traceback (most recent call last):
#   File "train.py", line 157, in <module>
#     trainer.train()
#   File "../semi_supervised_AD/trainer/tgconv_ngat_cluster_trainer2.py", line 184, in train
#     loss.backward()
#   File "/usr/local/lib/python3.8/dist-packages/torch/tensor.py", line 245, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py", line 145, in backward
#     Variable._execution_engine.run_backward(
# RuntimeError: CUDA out of memory. Tried to allocate 66.00 MiB (GPU 1; 11.91 GiB total capacity; 10.12 GiB already allocated; 65.56 MiB free; 10.46 GiB reserved in total by PyTorch)
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT18635_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCluster2_1NTT18635_naive_itv_72_h32_SVM_rs1234
# model_name: TGConvNGATCluster2_1NTT18635_naive_itv_72_h32_SVM_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 8
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT18635_naive_itv_72_h32_rs1234
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.27033946 0.72966054]
# [[ 1.4500735  -1.2973002   0.8299655   1.7794205  -2.0133576 ]
#  [ 1.5682743   0.08623715  1.4568944   0.06789875  0.40771013]]
# Epoch: 0 / 100 | Train Time: 697.821 | Train Loss: 0.197337; Center Loss: 0.231540; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.197337;
# Val ACC | p0:0.884, p1:0.971, r0:0.889, r1:0.649, f1:0.750.
# Test ACC | p0:0.961, p1:0.971, r0:0.921, r1:0.897, f1:0.909.
# >>> Models have been saved.
# 20.330683 -24.483538
# 0.7849759 13.896319
# 20.330683 -24.483538
# 0.7849759 13.896319
# [[ 1.4500487  -1.2973095   0.8299404   1.7794344  -2.0133753 ]
#  [ 1.5682743   0.08626374  1.4568995   0.06786029  0.4077569 ]]
# Epoch: 1 / 100 | Train Time: 682.020 | Train Loss: 0.074856; Center Loss: 0.089233; Unsup Center Loss: 0.000000; CE Loss: 0.000000; Center Distance: 0.000000; KL Loss: 0.074856;
# Val ACC | p0:0.905, p1:0.931, r0:0.794, r1:0.730, f1:0.761.
# Test ACC | p0:0.968, p1:0.902, r0:0.783, r1:0.923, f1:0.847.
# >>> Models have been saved.
# -10.724365 -29.339447
# 17.501526 29.455873
# -10.724365 -29.339447
# 17.501526 29.455873

# %%
""" building models """

# ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', 
#  '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']
# ['1G4F0BP', '14VQMGH', '1NTT18927', '167X3XL3', '1NTT19535', '1NTT67246', '1NTT62166', 
# '1NTT19478', '157FU0B', '1NTT33624', '143XB8CT', '12V0BC9N', '1NTT30990', '1NTT24436', 
# '1NTT48337', '1NTT19213', '11NTMBPZ', '15CU4196', '1WEH98', '1NTT22885', '14ZI7ZUN', '1RA2O96', '1NTT18635', '1NTT62846']

networks = ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', 
            '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT18635']

larger_networks = ['1NTT19478', '1NTT19213', '1NTT18635']

for seed in [4321, 1111]:
    for i, network in enumerate(networks): # networks[1:2]):

        base_dir = '/data/yijun/NTT/'
        data_name = f'{network}_naive_itv_72'
        data_path = os.path.join(base_dir, f'graph-data/08/{data_name}')

        if not os.path.exists(data_path):
            print(network)
            continue


    #     processed_path = os.path.join(data_path, f'processed')
    #     if os.path.exists(processed_path):
    #         shutil.rmtree(processed_path)

        num_classes = 2
        h_dim = 32
        graph_h_dim = 256 
        batch_size = 16 if network not in larger_networks else 8
        random_seed = seed
        predict_func = 'SVM'
        ae_model_name = f'TGConvNGATAE_{data_name}_h{h_dim}_rs{random_seed}'

        model_name = f'TGConvNGATCC_UN_{data_name}_h{h_dim}_{predict_func}_rs{random_seed}'
        res_path = os.path.join(base_dir, f'model-results-1006')    
        if not os.path.exists(res_path):
            os.mkdir(res_path)        
        res_path = os.path.join(res_path, model_name)

        # !python3.8 train.py \
        --data_path $data_path \
        --res_path $res_path \
        --model_name $model_name \
        --pretrain_model_name $ae_model_name \
        --num_classes $num_classes \
        --h_dim $h_dim \
        --batch_size $batch_size \
        --predict_func $predict_func \
        --lr 0.001 \
        --eta 1 \
        --use_unlabel \
        --device 1 \
        --random_seed $random_seed \
        --epochs 100
# Out:
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT18927_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCC_UN_1NTT18927_naive_itv_72_h32_SVM_rs4321
# model_name: TGConvNGATCC_UN_1NTT18927_naive_itv_72_h32_SVM_rs4321
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 4321
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 16
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT18927_naive_itv_72_h32_rs4321
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.03755801 0.96244199]
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621034]
#  [ 0.28826126 -1.6405035   0.07799394  1.2124738   0.5130408 ]]
# Epoch: 0 / 100 | Train Time: 164.638 | Train Loss: 0.019687; Center Loss: 0.016119; Unsup Center Loss: 0.000000; CE Loss: 0.767501; Center Distance: 508.728744; KL Loss: 0.000000;
# Val ACC | p0:0.989, p1:0.955, r0:0.383, r1:0.720, f1:0.500.
# Test ACC | p0:0.989, p1:0.952, r0:0.367, r1:0.720, f1:0.486.
# >>> Models have been saved.
# -52.456097 43.06686
# 36.46378 -14.343519
# -52.456097 43.06686
# 36.46378 -14.343519
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621035]
#  [ 0.28826126 -1.6405035   0.0779938   1.2124738   0.5130408 ]]
# Epoch: 1 / 100 | Train Time: 163.678 | Train Loss: 0.012842; Center Loss: 0.012578; Unsup Center Loss: 0.000000; CE Loss: 0.767861; Center Distance: 508.728949; KL Loss: 0.000000;
# Val ACC | p0:0.986, p1:0.966, r0:0.421, r1:0.640, f1:0.508.
# Test ACC | p0:0.987, p1:0.949, r0:0.340, r1:0.680, f1:0.453.
# >>> Models have been saved.
# -10.823519 -29.13993
# -11.765835 24.342714
# -10.823519 -29.13993
# -11.765835 24.342714
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621035]
#  [ 0.28826126 -1.6405035   0.07799351  1.2124738   0.5130408 ]]
# Epoch: 2 / 100 | Train Time: 161.308 | Train Loss: 0.012553; Center Loss: 0.012268; Unsup Center Loss: 0.000000; CE Loss: 0.768043; Center Distance: 508.729004; KL Loss: 0.000000;
# Val ACC | p0:0.985, p1:0.944, r0:0.308, r1:0.640, f1:0.416.
# Test ACC | p0:0.989, p1:0.967, r0:0.462, r1:0.720, f1:0.562.
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621035]
#  [ 0.28826126 -1.6405035   0.07799351  1.2124738   0.5130408 ]]
# Epoch: 3 / 100 | Train Time: 161.655 | Train Loss: 0.012259; Center Loss: 0.011990; Unsup Center Loss: 0.000000; CE Loss: 0.772240; Center Distance: 508.729004; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.963, r0:0.442, r1:0.760, f1:0.559.
# Test ACC | p0:0.992, p1:0.964, r0:0.465, r1:0.800, f1:0.588.
# >>> Models have been saved.
# 0.9796356 43.10071
# -8.372779 -41.89288
# 0.9796356 43.10071
# -8.372779 -41.89288
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.2462103 ]
#  [ 0.28826126 -1.6405035   0.0779935   1.2124738   0.5130408 ]]
# Epoch: 4 / 100 | Train Time: 163.740 | Train Loss: 0.012189; Center Loss: 0.011835; Unsup Center Loss: 0.000000; CE Loss: 0.771960; Center Distance: 508.729004; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.961, r0:0.432, r1:0.760, f1:0.551.
# Test ACC | p0:0.992, p1:0.956, r0:0.417, r1:0.800, f1:0.548.
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.2462103 ]
#  [ 0.28826126 -1.6405035   0.0779934   1.2124738   0.5130408 ]]
# Epoch: 5 / 100 | Train Time: 162.696 | Train Loss: 0.012143; Center Loss: 0.011706; Unsup Center Loss: 0.000000; CE Loss: 0.772955; Center Distance: 508.729026; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.925, r0:0.284, r1:0.760, f1:0.413.
# Test ACC | p0:0.993, p1:0.916, r0:0.280, r1:0.840, f1:0.420.
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.2462103 ]
#  [ 0.28826126 -1.6405035   0.07799338  1.2124738   0.5130408 ]]
# Epoch: 6 / 100 | Train Time: 163.583 | Train Loss: 0.012130; Center Loss: 0.011792; Unsup Center Loss: 0.000000; CE Loss: 0.769723; Center Distance: 508.729053; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.959, r0:0.422, r1:0.760, f1:0.543.
# Test ACC | p0:0.994, p1:0.956, r0:0.429, r1:0.840, f1:0.568.
# Val loss does not decrease for 3 epochs.
# New learning rate: 0.0001.
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621035]
#  [ 0.28826126 -1.6405035   0.07799338  1.2124738   0.5130408 ]]
# Epoch: 7 / 100 | Train Time: 161.070 | Train Loss: 0.011993; Center Loss: 0.011593; Unsup Center Loss: 0.000000; CE Loss: 0.774138; Center Distance: 508.729065; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.959, r0:0.422, r1:0.760, f1:0.543.
# Test ACC | p0:0.992, p1:0.955, r0:0.408, r1:0.800, f1:0.541.
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621035]
#  [ 0.28826126 -1.6405035   0.07799342  1.2124738   0.5130408 ]]
# Epoch: 8 / 100 | Train Time: 162.376 | Train Loss: 0.011993; Center Loss: 0.011614; Unsup Center Loss: 0.000000; CE Loss: 0.770572; Center Distance: 508.729062; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.959, r0:0.422, r1:0.760, f1:0.543.
# Test ACC | p0:0.992, p1:0.956, r0:0.417, r1:0.800, f1:0.548.
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621035]
#  [ 0.28826126 -1.6405035   0.07799347  1.2124738   0.5130408 ]]
# Epoch: 9 / 100 | Train Time: 160.180 | Train Loss: 0.012023; Center Loss: 0.011615; Unsup Center Loss: 0.000000; CE Loss: 0.773922; Center Distance: 508.729047; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.953, r0:0.388, r1:0.760, f1:0.514.
# Test ACC | p0:0.993, p1:0.949, r0:0.389, r1:0.840, f1:0.532.
# [[ 0.5239358  -1.2773615   1.7941604   1.7068157   0.24621035]
#  [ 0.28826126 -1.6405035   0.07799347  1.2124738   0.5130408 ]]
# Epoch: 10 / 100 | Train Time: 164.026 | Train Loss: 0.011935; Center Loss: 0.011514; Unsup Center Loss: 0.000000; CE Loss: 0.773640; Center Distance: 508.729032; KL Loss: 0.000000;
# Val ACC | p0:0.990, p1:0.959, r0:0.422, r1:0.760, f1:0.543.
# Test ACC | p0:0.989, p1:0.945, r0:0.340, r1:0.720, f1:0.462.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT19535_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCC_UN_1NTT19535_naive_itv_72_h32_SVM_rs4321
# model_name: TGConvNGATCC_UN_1NTT19535_naive_itv_72_h32_SVM_rs4321
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 4321
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 16
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT19535_naive_itv_72_h32_rs4321
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.10842215 0.89157785]
# [[-0.96802235  0.12262801  0.41800746  1.2881272  -1.8404197 ]
#  [-1.1568453  -1.7620885  -1.2348573  -0.07641868  0.8862502 ]]
# Epoch: 0 / 100 | Train Time: 279.307 | Train Loss: 0.040960; Center Loss: 0.038055; Unsup Center Loss: 0.000000; CE Loss: 0.719141; Center Distance: 450.715221; KL Loss: 0.000000;
# Val ACC | p0:0.964, p1:0.919, r0:0.513, r1:0.714, f1:0.597.
# Test ACC | p0:0.969, p1:0.927, r0:0.564, r1:0.759, f1:0.647.
# >>> Models have been saved.
# 14.484331 -16.137413
# 5.970981 25.875526
# 14.484331 -16.137413
# 5.970981 25.875526
# [[-0.9680218   0.12262844  0.41800767  1.2881274  -1.8404202 ]
#  [-1.1568453  -1.7620885  -1.2348573  -0.07641931  0.8862513 ]]
# Epoch: 1 / 100 | Train Time: 276.593 | Train Loss: 0.034040; Center Loss: 0.031264; Unsup Center Loss: 0.000000; CE Loss: 0.721526; Center Distance: 450.717436; KL Loss: 0.000000;
# Val ACC | p0:0.951, p1:0.919, r0:0.472, r1:0.607, f1:0.531.
# Test ACC | p0:0.962, p1:0.966, r0:0.714, r1:0.690, f1:0.702.
# [[-0.9680206   0.12262989  0.41800842  1.2881278  -1.840421  ]
#  [-1.1568453  -1.7620885  -1.2348573  -0.07642047  0.88625234]]
# Epoch: 2 / 100 | Train Time: 273.810 | Train Loss: 0.032819; Center Loss: 0.029337; Unsup Center Loss: 0.000000; CE Loss: 0.720678; Center Distance: 450.718031; KL Loss: 0.000000;
# Val ACC | p0:0.969, p1:0.932, r0:0.568, r1:0.750, f1:0.646.
# Test ACC | p0:0.973, p1:0.936, r0:0.605, r1:0.793, f1:0.687.
# >>> Models have been saved.
# 9.063876 -15.86851
# -30.34124 1.5526142
# 9.063876 -15.86851
# -30.34124 1.5526142
# [[-0.96801984  0.1226312   0.41800934  1.2881279  -1.8404213 ]
#  [-1.1568453  -1.7620885  -1.2348573  -0.076421    0.8862526 ]]
# Epoch: 3 / 100 | Train Time: 273.381 | Train Loss: 0.031425; Center Loss: 0.027813; Unsup Center Loss: 0.000000; CE Loss: 0.719729; Center Distance: 450.718605; KL Loss: 0.000000;
# Val ACC | p0:0.969, p1:0.923, r0:0.538, r1:0.750, f1:0.627.
# Test ACC | p0:0.986, p1:0.923, r0:0.591, r1:0.897, f1:0.712.
# [[-0.9680192   0.12263206  0.41800973  1.2881263  -1.8404195 ]
#  [-1.1568453  -1.7620885  -1.2348573  -0.07642138  0.8862523 ]]
# Epoch: 4 / 100 | Train Time: 273.002 | Train Loss: 0.030766; Center Loss: 0.026675; Unsup Center Loss: 0.000000; CE Loss: 0.718298; Center Distance: 450.718775; KL Loss: 0.000000;
# Val ACC | p0:0.959, p1:0.897, r0:0.442, r1:0.679, f1:0.535.
# Test ACC | p0:0.973, p1:0.915, r0:0.535, r1:0.793, f1:0.639.
# [[-0.9680185   0.12263217  0.41800943  1.2881254  -1.8404183 ]
#  [-1.1568453  -1.7620885  -1.2348573  -0.07642115  0.8862505 ]]
# Epoch: 5 / 100 | Train Time: 272.903 | Train Loss: 0.030242; Center Loss: 0.026207; Unsup Center Loss: 0.000000; CE Loss: 0.717578; Center Distance: 450.718166; KL Loss: 0.000000;
# Val ACC | p0:0.948, p1:0.927, r0:0.485, r1:0.571, f1:0.525.
# Test ACC | p0:0.969, p1:0.949, r0:0.647, r1:0.759, f1:0.698.
# Val loss does not decrease for 3 epochs.
# New learning rate: 0.0001.
# [[-0.9680191   0.12262542  0.41800404  1.2881225  -1.8404064 ]
#  [-1.1568453  -1.7620885  -1.2348573  -0.07641731  0.886242  ]]
# Epoch: 6 / 100 | Train Time: 272.662 | Train Loss: 0.026669; Center Loss: 0.022567; Unsup Center Loss: 0.000000; CE Loss: 0.713769; Center Distance: 450.716372; KL Loss: 0.000000;
# Val ACC | p0:0.969, p1:0.923, r0:0.538, r1:0.750, f1:0.627.
# Test ACC | p0:0.977, p1:0.927, r0:0.585, r1:0.828, f1:0.686.
# [[-0.9680191   0.1226218   0.41800106  1.2881204  -1.8403987 ]
#  [-1.1568453  -1.7620884  -1.2348573  -0.07641391  0.886232  ]]
# Epoch: 7 / 100 | Train Time: 272.525 | Train Loss: 0.025143; Center Loss: 0.020824; Unsup Center Loss: 0.000000; CE Loss: 0.711311; Center Distance: 450.712903; KL Loss: 0.000000;
# Val ACC | p0:0.969, p1:0.944, r0:0.618, r1:0.750, f1:0.677.
# Test ACC | p0:0.978, p1:0.944, r0:0.649, r1:0.828, f1:0.727.
# >>> Models have been saved.
# 4.200757 40.902798
# 30.92981 -20.996607
# 4.200757 40.902798
# 30.92981 -20.996607
# [[-0.9680191   0.12261685  0.41799712  1.2881209  -1.8403867 ]
#  [-1.1568453  -1.7620884  -1.2348573  -0.07641061  0.88622224]]
# Epoch: 8 / 100 | Train Time: 272.596 | Train Loss: 0.024174; Center Loss: 0.019877; Unsup Center Loss: 0.000000; CE Loss: 0.708432; Center Distance: 450.710006; KL Loss: 0.000000;
# Val ACC | p0:0.964, p1:0.927, r0:0.541, r1:0.714, f1:0.615.
# Test ACC | p0:0.974, p1:0.944, r0:0.639, r1:0.793, f1:0.708.
# [[-0.9680191   0.12261137  0.41799277  1.2881196  -1.8403747 ]
#  [-1.1568453  -1.7620884  -1.2348573  -0.07640738  0.8862113 ]]
# Epoch: 9 / 100 | Train Time: 272.899 | Train Loss: 0.023383; Center Loss: 0.018928; Unsup Center Loss: 0.000000; CE Loss: 0.707820; Center Distance: 450.706738; KL Loss: 0.000000;
# Val ACC | p0:0.965, p1:0.944, r0:0.606, r1:0.714, f1:0.656.
# Test ACC | p0:0.970, p1:0.970, r0:0.759, r1:0.759, f1:0.759.
# [[-0.9680191   0.12260523  0.41798756  1.2881173  -1.8403623 ]
#  [-1.1568453  -1.7620884  -1.2348573  -0.07640382  0.8861969 ]]
# Epoch: 10 / 100 | Train Time: 273.961 | Train Loss: 0.022408; Center Loss: 0.018038; Unsup Center Loss: 0.000000; CE Loss: 0.706246; Center Distance: 450.703515; KL Loss: 0.000000;
# Val ACC | p0:0.961, p1:0.953, r0:0.633, r1:0.679, f1:0.655.
# Test ACC | p0:0.975, p1:0.983, r0:0.852, r1:0.793, f1:0.821.
# Val loss does not decrease for 3 epochs.
# New learning rate: 1e-05.
# [[-0.9680191   0.12260248  0.41798568  1.2881182  -1.8403587 ]
#  [-1.1568453  -1.7620883  -1.2348573  -0.07640029  0.8861846 ]]
# Epoch: 11 / 100 | Train Time: 274.365 | Train Loss: 0.021382; Center Loss: 0.017061; Unsup Center Loss: 0.000000; CE Loss: 0.704862; Center Distance: 450.700836; KL Loss: 0.000000;
# Val ACC | p0:0.961, p1:0.944, r0:0.594, r1:0.679, f1:0.633.
# Test ACC | p0:0.974, p1:0.974, r0:0.793, r1:0.793, f1:0.793.
# [[-0.9680191   0.12259708  0.41798168  1.288118   -1.84035   ]
#  [-1.1568453  -1.7620882  -1.2348573  -0.07639651  0.8861711 ]]
# Epoch: 12 / 100 | Train Time: 276.035 | Train Loss: 0.021573; Center Loss: 0.017279; Unsup Center Loss: 0.000000; CE Loss: 0.706105; Center Distance: 450.697824; KL Loss: 0.000000;
# Val ACC | p0:0.961, p1:0.940, r0:0.576, r1:0.679, f1:0.623.
# Test ACC | p0:0.970, p1:0.970, r0:0.759, r1:0.759, f1:0.759.
# [[-0.9680191   0.12259137  0.41797718  1.288118   -1.8403449 ]
#  [-1.1568453  -1.7620882  -1.2348573  -0.07639314  0.88615704]]
# Epoch: 13 / 100 | Train Time: 273.536 | Train Loss: 0.021210; Center Loss: 0.016973; Unsup Center Loss: 0.000000; CE Loss: 0.702921; Center Distance: 450.694708; KL Loss: 0.000000;
# Val ACC | p0:0.961, p1:0.936, r0:0.559, r1:0.679, f1:0.613.
# Test ACC | p0:0.970, p1:0.970, r0:0.759, r1:0.759, f1:0.759.
# [[-0.9680191   0.1225848   0.4179722   1.288118   -1.8403355 ]
#  [-1.1568453  -1.7620882  -1.2348573  -0.07638984  0.88614255]]
# Epoch: 14 / 100 | Train Time: 273.712 | Train Loss: 0.021310; Center Loss: 0.016932; Unsup Center Loss: 0.000000; CE Loss: 0.704103; Center Distance: 450.691400; KL Loss: 0.000000;
# Val ACC | p0:0.961, p1:0.940, r0:0.576, r1:0.679, f1:0.623.
# Test ACC | p0:0.970, p1:0.979, r0:0.815, r1:0.759, f1:0.786.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT67246_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCC_UN_1NTT67246_naive_itv_72_h32_SVM_rs4321
# model_name: TGConvNGATCC_UN_1NTT67246_naive_itv_72_h32_SVM_rs4321
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 4321
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 16
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT67246_naive_itv_72_h32_rs4321
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.08801211 0.91198789]
# [[ 1.1216823   0.76536447  0.85549957  0.15374118 -1.1224841 ]
#  [-0.38553825 -1.1367284  -0.35301766  0.141334    0.5638785 ]]
# Epoch: 0 / 100 | Train Time: 207.039 | Train Loss: 0.033706; Center Loss: 0.030322; Unsup Center Loss: 0.000000; CE Loss: 0.733340; Center Distance: 517.891607; KL Loss: 0.000000;
# Val ACC | p0:0.973, p1:0.921, r0:0.463, r1:0.731, f1:0.567.
# Test ACC | p0:0.992, p1:0.935, r0:0.591, r1:0.929, f1:0.722.
# >>> Models have been saved.
# -34.34464 4.3353567
# 17.81719 25.520365
# -34.34464 4.3353567
# 17.81719 25.520365
# [[ 1.1216822   0.76536477  0.8554997   0.15374118 -1.1224841 ]
#  [-0.38553882 -1.1367284  -0.35301816  0.141334    0.5638792 ]]
# Epoch: 1 / 100 | Train Time: 207.002 | Train Loss: 0.027824; Center Loss: 0.026394; Unsup Center Loss: 0.000000; CE Loss: 0.733573; Center Distance: 517.892142; KL Loss: 0.000000;
# Val ACC | p0:0.959, p1:0.834, r0:0.258, r1:0.615, f1:0.364.
# Test ACC | p0:0.974, p1:0.820, r0:0.306, r1:0.786, f1:0.440.
# [[ 1.1216822   0.76536494  0.85549974  0.15374118 -1.1224841 ]
#  [-0.38553882 -1.1367284  -0.35301816  0.141334    0.5638792 ]]
# Epoch: 2 / 100 | Train Time: 204.491 | Train Loss: 0.027582; Center Loss: 0.026380; Unsup Center Loss: 0.000000; CE Loss: 0.733852; Center Distance: 517.892631; KL Loss: 0.000000;
# Val ACC | p0:0.975, p1:0.848, r0:0.323, r1:0.769, f1:0.455.
# Test ACC | p0:0.968, p1:0.874, r0:0.364, r1:0.714, f1:0.482.
# [[ 1.1216822   0.7653648   0.85549974  0.15374118 -1.1224841 ]
#  [-0.38553882 -1.1367284  -0.35301816  0.141334    0.5638792 ]]
# Epoch: 3 / 100 | Train Time: 199.576 | Train Loss: 0.027396; Center Loss: 0.025941; Unsup Center Loss: 0.000000; CE Loss: 0.732067; Center Distance: 517.892740; KL Loss: 0.000000;
# Val ACC | p0:0.973, p1:0.903, r0:0.413, r1:0.731, f1:0.528.
# Test ACC | p0:0.985, p1:0.917, r0:0.511, r1:0.857, f1:0.640.
# Val loss does not decrease for 3 epochs.
# New learning rate: 0.0001.
# [[ 1.1216822   0.7653647   0.85549974  0.15374118 -1.1224841 ]
#  [-0.38553882 -1.1367284  -0.35301816  0.141334    0.5638792 ]]
# Epoch: 4 / 100 | Train Time: 198.675 | Train Loss: 0.025907; Center Loss: 0.024402; Unsup Center Loss: 0.000000; CE Loss: 0.732323; Center Distance: 517.892745; KL Loss: 0.000000;
# Val ACC | p0:0.973, p1:0.917, r0:0.452, r1:0.731, f1:0.559.
# Test ACC | p0:0.984, p1:0.892, r0:0.444, r1:0.857, f1:0.585.
# [[ 1.1216822   0.7653653   0.85549974  0.15374118 -1.1224841 ]
#  [-0.38553882 -1.1367284  -0.35301816  0.141334    0.5638792 ]]
# Epoch: 5 / 100 | Train Time: 198.752 | Train Loss: 0.025423; Center Loss: 0.023510; Unsup Center Loss: 0.000000; CE Loss: 0.734131; Center Distance: 517.892694; KL Loss: 0.000000;
# Val ACC | p0:0.974, p1:0.935, r0:0.514, r1:0.731, f1:0.603.
# Test ACC | p0:0.985, p1:0.917, r0:0.511, r1:0.857, f1:0.640.
# >>> Models have been saved.
# -24.711628 -8.952534
# 27.931644 4.0489855
# -24.711628 -8.952534
# 27.931644 4.0489855
# [[ 1.1216822   0.76536506  0.85550016  0.15374118 -1.1224841 ]
#  [-0.38553876 -1.1367284  -0.35301813  0.141334    0.5638792 ]]
# Epoch: 6 / 100 | Train Time: 199.088 | Train Loss: 0.025502; Center Loss: 0.023349; Unsup Center Loss: 0.000000; CE Loss: 0.735673; Center Distance: 517.892563; KL Loss: 0.000000;
# Val ACC | p0:0.968, p1:0.881, r0:0.353, r1:0.692, f1:0.468.
# Test ACC | p0:0.980, p1:0.881, r0:0.411, r1:0.821, f1:0.548.
# [[ 1.1216822   0.7653651   0.8555001   0.15374118 -1.1224841 ]
#  [-0.38553864 -1.1367284  -0.35301813  0.141334    0.5638792 ]]
# Epoch: 7 / 100 | Train Time: 199.115 | Train Loss: 0.024985; Center Loss: 0.022759; Unsup Center Loss: 0.000000; CE Loss: 0.733037; Center Distance: 517.892458; KL Loss: 0.000000;
# Val ACC | p0:0.965, p1:0.892, r0:0.362, r1:0.654, f1:0.466.
# Test ACC | p0:0.976, p1:0.878, r0:0.393, r1:0.786, f1:0.524.
# [[ 1.1216822   0.7653643   0.8555003   0.15374118 -1.1224841 ]
#  [-0.3855386  -1.1367284  -0.35301813  0.141334    0.5638792 ]]
# Epoch: 8 / 100 | Train Time: 201.212 | Train Loss: 0.025476; Center Loss: 0.023158; Unsup Center Loss: 0.000000; CE Loss: 0.735550; Center Distance: 517.892330; KL Loss: 0.000000;
# Val ACC | p0:0.973, p1:0.917, r0:0.452, r1:0.731, f1:0.559.
# Test ACC | p0:0.984, p1:0.888, r0:0.436, r1:0.857, f1:0.578.
# Val loss does not decrease for 3 epochs.
# New learning rate: 1e-05.
# [[ 1.1216803   0.76536244  0.85549873  0.15374118 -1.1224818 ]
#  [-0.38553828 -1.1367284  -0.35301802  0.141334    0.5638792 ]]
# Epoch: 9 / 100 | Train Time: 198.963 | Train Loss: 0.024356; Center Loss: 0.021951; Unsup Center Loss: 0.000000; CE Loss: 0.731671; Center Distance: 517.891502; KL Loss: 0.000000;
# Val ACC | p0:0.970, p1:0.924, r0:0.462, r1:0.692, f1:0.554.
# Test ACC | p0:0.984, p1:0.899, r0:0.462, r1:0.857, f1:0.600.
# [[ 1.1216803   0.7653624   0.85549873  0.15374118 -1.1224818 ]
#  [-0.38553825 -1.1367284  -0.35301802  0.141334    0.5638792 ]]
# Epoch: 10 / 100 | Train Time: 198.839 | Train Loss: 0.024489; Center Loss: 0.022196; Unsup Center Loss: 0.000000; CE Loss: 0.732342; Center Distance: 517.891333; KL Loss: 0.000000;
# Val ACC | p0:0.973, p1:0.921, r0:0.463, r1:0.731, f1:0.567.
# Test ACC | p0:0.984, p1:0.892, r0:0.444, r1:0.857, f1:0.585.
# [[ 1.1216803   0.7653624   0.85549873  0.15374118 -1.1224818 ]
#  [-0.38553813 -1.1367284  -0.35301802  0.141334    0.5638792 ]]
# Epoch: 11 / 100 | Train Time: 200.804 | Train Loss: 0.024617; Center Loss: 0.022190; Unsup Center Loss: 0.000000; CE Loss: 0.734579; Center Distance: 517.891136; KL Loss: 0.000000;
# Val ACC | p0:0.973, p1:0.921, r0:0.463, r1:0.731, f1:0.567.
# Test ACC | p0:0.984, p1:0.892, r0:0.444, r1:0.857, f1:0.585.
# [[ 1.1216803   0.76536196  0.85549873  0.15374118 -1.1224818 ]
#  [-0.38553792 -1.1367284  -0.35301796  0.141334    0.5638792 ]]
# Epoch: 12 / 100 | Train Time: 205.770 | Train Loss: 0.024343; Center Loss: 0.021950; Unsup Center Loss: 0.000000; CE Loss: 0.733311; Center Distance: 517.890863; KL Loss: 0.000000;
# Val ACC | p0:0.973, p1:0.917, r0:0.452, r1:0.731, f1:0.559.
# Test ACC | p0:0.984, p1:0.892, r0:0.444, r1:0.857, f1:0.585.
# device: 1
# data_path: /data/yijun/NTT/graph-data/08/1NTT19478_naive_itv_72
# res_path: /data/yijun/NTT/model-results-1006/TGConvNGATCC_UN_1NTT19478_naive_itv_72_h32_SVM_rs4321
# model_name: TGConvNGATCC_UN_1NTT19478_naive_itv_72_h32_SVM_rs4321
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 4321
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 8
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# use_pretrain: False
# pretrain_model_name: TGConvNGATAE_1NTT19478_naive_itv_72_h32_rs4321
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.11924519 0.88075481]
# [[ 0.04193331  1.583181    1.4478852  -0.06646541 -0.90263987]
#  [-1.0563793   0.05045055 -1.3863332   0.38216624 -0.67043304]]
# Epoch: 0 / 100 | Train Time: 539.223 | Train Loss: 0.096399; Center Loss: 0.089664; Unsup Center Loss: 0.000000; CE Loss: 0.725458; Center Distance: 480.732749; KL Loss: 0.000000;
# Val ACC | p0:0.935, p1:0.931, r0:0.500, r1:0.517, f1:0.508.
# Test ACC | p0:0.953, p1:0.927, r0:0.556, r1:0.667, f1:0.606.
# >>> Models have been saved.
# -16.182499 12.198187
# 10.43125 21.734003
# -16.182499 12.198187
# 10.43125 21.734003
# [[ 0.04194132  1.5831851   1.447901   -0.06646775 -0.90263736]
#  [-1.0563803   0.05043697 -1.3863466   0.38216767 -0.670433  ]]
# Epoch: 1 / 100 | Train Time: 538.754 | Train Loss: 0.086090; Center Loss: 0.078744; Unsup Center Loss: 0.000000; CE Loss: 0.729252; Center Distance: 480.743466; KL Loss: 0.000000;
# Val ACC | p0:0.930, p1:0.922, r0:0.452, r1:0.483, f1:0.467.
# Test ACC | p0:0.967, p1:0.941, r0:0.639, r1:0.767, f1:0.697.
# [[ 0.04194627  1.5831878   1.4479123  -0.06646869 -0.9026376 ]
#  [-1.0563803   0.0504278  -1.3863578   0.382168   -0.670433  ]]
# Epoch: 2 / 100 | Train Time: 538.125 | Train Loss: 0.084461; Center Loss: 0.077690; Unsup Center Loss: 0.000000; CE Loss: 0.729748; Center Distance: 480.751957; KL Loss: 0.000000;
# Val ACC | p0:0.969, p1:0.862, r0:0.434, r1:0.793, f1:0.561.
# Test ACC | p0:0.984, p1:0.863, r0:0.474, r1:0.900, f1:0.621.
# >>> Models have been saved.
# 15.554198 12.480015
# -13.59845 -6.361265
# 15.554198 12.480015
# -13.59845 -6.361265
# [[ 0.04195075  1.5831897   1.4479251  -0.0664692  -0.9026373 ]
#  [-1.0563805   0.05042103 -1.3863622   0.38216838 -0.670433  ]]
# Epoch: 3 / 100 | Train Time: 542.282 | Train Loss: 0.083460; Center Loss: 0.075253; Unsup Center Loss: 0.000000; CE Loss: 0.730852; Center Distance: 480.757548; KL Loss: 0.000000;
# Val ACC | p0:0.948, p1:0.922, r0:0.514, r1:0.621, f1:0.562.
# Test ACC | p0:0.953, p1:0.927, r0:0.556, r1:0.667, f1:0.606.
# >>> Models have been saved.
# 30.490555 3.078792
# -30.925459 -0.42670834
# 30.490555 3.078792
# -30.925459 -0.42670834
# [[ 0.04195377  1.5831927   1.4479342  -0.06647041 -0.9026374 ]
#  [-1.0563836   0.05041558 -1.3863686   0.38216925 -0.6704326 ]]
# Epoch: 4 / 100 | Train Time: 547.181 | Train Loss: 0.079955; Center Loss: 0.072397; Unsup Center Loss: 0.000000; CE Loss: 0.732135; Center Distance: 480.761872; KL Loss: 0.000000;
# Val ACC | p0:0.962, p1:0.940, r0:0.618, r1:0.724, f1:0.667.
# Test ACC | p0:0.967, p1:0.932, r0:0.605, r1:0.767, f1:0.676.
# >>> Models have been saved.
# 13.948294 30.840927
# -9.01792 34.125618
# 13.948294 30.840927
# -9.01792 34.125618
# [[ 0.0419555   1.5831935   1.447939   -0.0664705  -0.9026378 ]
#  [-1.0563843   0.05041264 -1.3863696   0.38216925 -0.6704326 ]]
# Epoch: 5 / 100 | Train Time: 539.303 | Train Loss: 0.078911; Center Loss: 0.070914; Unsup Center Loss: 0.000000; CE Loss: 0.732318; Center Distance: 480.766053; KL Loss: 0.000000;
# Val ACC | p0:0.956, p1:0.903, r0:0.488, r1:0.690, f1:0.571.
# Test ACC | p0:0.967, p1:0.941, r0:0.639, r1:0.767, f1:0.697.
# [[ 0.04195749  1.5831941   1.4479469  -0.06647082 -0.9026379 ]
#  [-1.056384    0.05041404 -1.3863665   0.38216907 -0.6704326 ]]
# Epoch: 6 / 100 | Train Time: 543.227 | Train Loss: 0.079423; Center Loss: 0.071394; Unsup Center Loss: 0.000000; CE Loss: 0.730831; Center Distance: 480.767995; KL Loss: 0.000000;
# Val ACC | p0:0.953, p1:0.945, r0:0.613, r1:0.655, f1:0.633.
# Test ACC | p0:0.968, p1:0.959, r0:0.719, r1:0.767, f1:0.742.
# [[ 0.04196033  1.5831989   1.4479553  -0.06647163 -0.9026374 ]
#  [-1.0563831   0.05041253 -1.386363    0.3821685  -0.6704326 ]]
# Epoch: 7 / 100 | Train Time: 545.933 | Train Loss: 0.078943; Center Loss: 0.069839; Unsup Center Loss: 0.000000; CE Loss: 0.732649; Center Distance: 480.769550; KL Loss: 0.000000;
# Val ACC | p0:0.949, p1:0.945, r0:0.600, r1:0.621, f1:0.610.
# Test ACC | p0:0.962, p1:0.936, r0:0.611, r1:0.733, f1:0.667.
# Val loss does not decrease for 3 epochs.
# New learning rate: 0.0001.
# [[ 0.04195585  1.5832008   1.4479487  -0.0664712  -0.9026374 ]
#  [-1.0563793   0.0504314  -1.3863238   0.38216522 -0.67043275]]
# Epoch: 8 / 100 | Train Time: 547.376 | Train Loss: 0.072530; Center Loss: 0.064082; Unsup Center Loss: 0.000000; CE Loss: 0.735704; Center Distance: 480.764416; KL Loss: 0.000000;
# Val ACC | p0:0.950, p1:0.963, r0:0.692, r1:0.621, f1:0.655.
# Test ACC | p0:0.959, p1:0.968, r0:0.750, r1:0.700, f1:0.724.
# [[ 0.0419556   1.5831972   1.447945   -0.06647141 -0.90263736]
#  [-1.056379    0.05044855 -1.3862855   0.38216436 -0.67043275]]
# Epoch: 9 / 100 | Train Time: 545.594 | Train Loss: 0.068922; Center Loss: 0.059697; Unsup Center Loss: 0.000000; CE Loss: 0.737296; Center Distance: 480.751544; KL Loss: 0.000000;
# Val ACC | p0:0.942, p1:0.977, r0:0.762, r1:0.552, f1:0.640.
# Test ACC | p0:0.955, p1:0.968, r0:0.741, r1:0.667, f1:0.702.
# [[ 0.04195447  1.5831946   1.4479321  -0.06647222 -0.9026372 ]
#  [-1.0563781   0.05046684 -1.3862404   0.38216344 -0.67043275]]
# Epoch: 10 / 100 | Train Time: 547.916 | Train Loss: 0.066929; Center Loss: 0.057090; Unsup Center Loss: 0.000000; CE Loss: 0.738510; Center Distance: 480.737836; KL Loss: 0.000000;
# Val ACC | p0:0.939, p1:0.995, r0:0.938, r1:0.517, f1:0.667.
# Test ACC | p0:0.947, p1:0.986, r0:0.857, r1:0.600, f1:0.706.
# [[ 0.0419534   1.5831873   1.4479114  -0.06647325 -0.90263796]
#  [-1.0563756   0.05048648 -1.3861902   0.38216236 -0.67043275]]
# Epoch: 11 / 100 | Train Time: 547.053 | Train Loss: 0.065125; Center Loss: 0.053848; Unsup Center Loss: 0.000000; CE Loss: 0.742465; Center Distance: 480.720805; KL Loss: 0.000000;
# Val ACC | p0:0.943, p1:0.995, r0:0.941, r1:0.552, f1:0.696.
# Test ACC | p0:0.935, p1:0.986, r0:0.833, r1:0.500, f1:0.625.
# >>> Models have been saved.
# -21.088457 -37.77412
# 3.0559418 42.037365
# -21.088457 -37.77412
# 3.0559418 42.037365
# [[ 0.04195326  1.5831805   1.4478842  -0.06647476 -0.9026377 ]
#  [-1.0563753   0.0505038  -1.3861407   0.38216233 -0.67043275]]
# Epoch: 12 / 100 | Train Time: 545.829 | Train Loss: 0.059633; Center Loss: 0.048455; Unsup Center Loss: 0.000000; CE Loss: 0.742132; Center Distance: 480.703256; KL Loss: 0.000000;
# Val ACC | p0:0.935, p1:0.991, r0:0.875, r1:0.483, f1:0.622.
# Test ACC | p0:0.923, p1:0.986, r0:0.800, r1:0.400, f1:0.533.
# [[ 0.04195055  1.583172    1.4478528  -0.06647521 -0.90263766]
#  [-1.0563723   0.05052353 -1.3860844   0.38216108 -0.67043275]]
# Epoch: 13 / 100 | Train Time: 548.824 | Train Loss: 0.056400; Center Loss: 0.044593; Unsup Center Loss: 0.000000; CE Loss: 0.744678; Center Distance: 480.684519; KL Loss: 0.000000;
# Val ACC | p0:0.926, p1:0.977, r0:0.706, r1:0.414, f1:0.522.
# Test ACC | p0:0.915, p1:0.977, r0:0.667, r1:0.333, f1:0.444.
# [[ 0.04195027  1.5831642   1.4478205  -0.06647582 -0.90263706]
#  [-1.0563698   0.05054368 -1.386025    0.38215995 -0.6704328 ]]
# Epoch: 14 / 100 | Train Time: 542.861 | Train Loss: 0.053447; Center Loss: 0.041032; Unsup Center Loss: 0.000000; CE Loss: 0.748042; Center Distance: 480.663499; KL Loss: 0.000000;
# Val ACC | p0:0.919, p1:0.995, r0:0.909, r1:0.345, f1:0.500.
# Test ACC | p0:0.919, p1:0.991, r0:0.846, r1:0.367, f1:0.512.
# Val loss does not decrease for 3 epochs.
# New learning rate: 1e-05.
# [[ 0.04194425  1.5831494   1.447773   -0.06647654 -0.902637  ]
#  [-1.0563686   0.05057081 -1.3859453   0.38215846 -0.6704328 ]]
# Epoch: 15 / 100 | Train Time: 538.578 | Train Loss: 0.048156; Center Loss: 0.036595; Unsup Center Loss: 0.000000; CE Loss: 0.750468; Center Distance: 480.635987; KL Loss: 0.000000;
# Val ACC | p0:0.915, p1:0.995, r0:0.900, r1:0.310, f1:0.462.
# Test ACC | p0:0.916, p1:0.991, r0:0.833, r1:0.333, f1:0.476.
# [[ 0.04193639  1.5831307   1.447722   -0.06647528 -0.9026365 ]
#  [-1.0563644   0.0505998  -1.3858625   0.382156   -0.6704328 ]]
# Epoch: 16 / 100 | Train Time: 542.085 | Train Loss: 0.046871; Center Loss: 0.035383; Unsup Center Loss: 0.000000; CE Loss: 0.751531; Center Distance: 480.606361; KL Loss: 0.000000;
# Val ACC | p0:0.915, p1:0.995, r0:0.900, r1:0.310, f1:0.462.
# Test ACC | p0:0.916, p1:0.991, r0:0.833, r1:0.333, f1:0.476.

# %%
""" building models """

# ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', 
#  '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']
# ['1G4F0BP', '14VQMGH', '1NTT18927', '167X3XL3', '1NTT19535', '1NTT67246', '1NTT62166', 
# '1NTT19478', '157FU0B', '1NTT33624', '143XB8CT', '12V0BC9N', '1NTT30990', '1NTT24436', 
# '1NTT48337', '1NTT19213', '11NTMBPZ', '15CU4196', '1WEH98', '1NTT22885', '14ZI7ZUN', '1RA2O96', '1NTT18635', '1NTT62846']

networks = ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', 
            '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT18635']

for i, network in enumerate(networks): # networks[1:2]):

    base_dir = '/data/yijun/NTT/'
    data_name = f'{network}_naive_itv_72'
    data_path = os.path.join(base_dir, f'graph-data/08/{data_name}')
    
    if not os.path.exists(data_path):
        print(network)
        continue
        
    
#     processed_path = os.path.join(data_path, f'processed')
#     if os.path.exists(processed_path):
#         shutil.rmtree(processed_path)

    num_classes = 2
    h_dim = 32
    graph_h_dim = 256 
    batch_size = 16
    random_seed = 1111
    predict_func = 'SVM'
    ae_model_name = f'TGConvNGATAE_{data_name}_h{h_dim}_rs{random_seed}'
    
    model_name = f'TGConvNGATCC_{data_name}_h{h_dim}_{predict_func}_rs{random_seed}'
    res_path = os.path.join(base_dir, f'model-results-1006')    
    if not os.path.exists(res_path):
        os.mkdir(res_path)        
    res_path = os.path.join(res_path, model_name)
    
    # !python3.8 train.py \
    --data_path $data_path \
    --res_path $res_path \
    --model_name $model_name \
    --pretrain_model_name $ae_model_name \
    --num_classes $num_classes \
    --h_dim $h_dim \
    --batch_size $batch_size \
    --predict_func $predict_func \
    --lr 0.001 \
    --eta 1 \
    --use_unlabel \
    --device 2 \
    --random_seed $random_seed \
    --epochs 100

# %% [markdown]
# ## Test

# %%
""" testing a given model and generating embeddings """

base_dir = '/data/yijun/NTT'
for network in ['1NTT18927']:

    data_name = f'{network}_naive_itv_72'
    data_path = os.path.join(base_dir, f'graph-data/08/{data_name}')
    if not os.path.exists(data_path):
        continue

#     processed_path = os.path.join(data_path, f'processed')
#     if os.path.exists(processed_path):
#         shutil.rmtree(processed_path)
        
    num_classes = 2
    h_dim = 32 
    graph_h_dim = 256 
    batch_size = 16
    random_seed = 1234
    ae_model_name = 'TGConvNGATAE_1NTT18927_naive_itv_72_h32_b16_rs1234'
    
    model_name = f'TGConvNGAT_{data_name}_h{h_dim}_b{batch_size}_rs{random_seed}'
    res_path = os.path.join(base_dir, f'model-results-0912')    
    res_path = os.path.join(res_path, model_name)

    if not os.path.exists(res_path):
        continue

    # !python3.8 test.py \
    --data_path $data_path \
    --res_path $res_path \
    --model_name $model_name \
    --ae_model_name $ae_model_name \
    --num_classes $num_classes \
    --h_dim $h_dim \
    --batch_size $batch_size \
    --lr 0.001 \
    --eta 1 \
    --use_unlabel \
    --device 2 \
    --random_seed $random_seed
# Out:
# device: 2
# data_path: /data/yijun/NTT/graph-data/08/1NTT18927_naive_itv_72
# res_path: /data/yijun/NTT/model-results-0912/TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234
# model_name: TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234
# ae_model_name: TGConvNGATAE_1NTT18927_naive_itv_72_h32_b16_rs1234
# num_classes: 2
# n_pos_samples: -1
# n_neg_samples: -1
# shuffle: True
# random_seed: 1234
# lr: 0.001
# lr_center: 0.0001
# weight_decay: 0.0001
# epochs: 100
# batch_size: 16
# patience: 7
# log_interval: 1
# use_node_aux_attr: False
# use_graph_aux_attr: False
# use_unlabel: True
# h_dim: 32
# graph_h_dim: 256
# predict_func: SVM
# num_attn_layers: 1
# eta: 1.0
# use_tb: False
# tb_path:
# verbose: True
# weighted labels: [0.03755801 0.96244199]
# Traceback (most recent call last):
#   File "test.py", line 43, in <module>
#     model.load_state_dict(torch.load(model_path))
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 579, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.8/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/data/yijun/NTT/model-results-0912/TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234/models/model.pkl'

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### A. Visualizing Images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# for network in ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']:

network = '1NTT18927'
model_name = f'TGConvNGAT_1NTT18927_naive_itv_72_h32_b16_rs1234'
res_path = os.path.join(base_dir, f'model-results-0912/{model_name}')    
image_path = os.path.join(res_path, 'img')

figures = dict()
n_cols = 2

label_image, prediction_image = None, None
for i in range(20):
    f1 = os.path.join(image_path, f'{i}_label.png')    
    f2 = os.path.join(image_path, f'{i}_prediction.png')    
    if not os.path.exists(f1) or not os.path.exists(f2):
        continue
    label_image, prediction_image = f1, f2

fig = plt.figure(figsize=(15, 15))
axes = []
axes.append( fig.add_subplot(1, 2, 1) )
axes[-1].set_title(f'{network} Label')  
plt.imshow(mpimg.imread(label_image))
plt.xticks([])
plt.yticks([])

axes.append( fig.add_subplot(1, 2, 2) )
axes[-1].set_title(f'{network} Prediction')  
plt.imshow(mpimg.imread(prediction_image))

plt.xticks([])
plt.yticks([])
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6289/2091227005.py in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 import matplotlib.image as mpimg
#       3
#       4 # for network in ['1NTT18927', '1NTT19535', '1NTT67246', '1NTT19478', '143XB8CT', '1NTT30990', '1NTT48337', '1NTT19213', '1NTT22885', '1NTT62846']:
#       5
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in <module>
#     821 # triggering resolution of _auto_backend_sentinel.
#     822 rcParamsDefault = _rc_params_in_file(
# --> 823     cbook._get_data_path("matplotlibrc"),
#     824     # Strip leading comment.
#     825     transform=lambda line: line[1:] if line.startswith("#") else line,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py in _get_data_path(*args)
#     532     ``*args`` specify a path relative to the base data path.
#     533     """
# --> 534     return Path(matplotlib.get_data_path(), *args)
#     535
#     536
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'

# %% [markdown]
# ### B. Visualizing ROC curve

# %%
from utils.plot_utils import draw_roc_curve

model_name = f'GATConv_{network}_naive_itv_60_led_0_attn1_h256_b128_shuffle'
res_path = os.path.join(base_dir, f'model-results-0316/{model_name}')    

results = np.load(os.path.join(res_path, 'result.npz'))
draw_roc_curve(results['embedding'], results['label'])

# %%
"""
data | data_path: /data/yijun/NTT/graph-data/1NTT62846_naive_itv_60_led_0
data | res_path: /data/yijun/NTT/model-results-0328/GATConvCVAE_1NTT62846_naive_itv_60_led_0_feat0_h256_b128_shuffle
weighted labels: [0.02262073 0.97737927]
Testing - p0:0.985, r0:0.858, p1:0.086, r1:0.500, f:0.147.
All - p0:0.995, r0:0.885, p1:0.138, r1:0.791, f:0.234.
"""

results = dict() 

with open('results.txt', 'r') as f:
    for line in f:
        if 'data | data_path' in line:
            data_name = line.split('/')[-1].split('_')[0]
            if results.get(data_name) is None:
                results[data_name] = dict()
        if 'data | res_path' in line:
            model_name = line.split('/')[-1]
            model_type = model_name.split('_')[0]
            num_features = int(model_name.split('_')[7][4:])
            h_dim = int(model_name.split('_')[8][1:])
            batch_size = int(model_name.split('_')[9][1:])            
        if 'Testing' in line:
            items = line.split(':')
            results[data_name][(model_type, num_features, h_dim, batch_size, 'p0')] = float(items[1][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'r0')] = float(items[2][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'p1')] = float(items[3][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'r1')] = float(items[4][:5])
            results[data_name][(model_type, num_features, h_dim, batch_size, 'f1')] = float(items[5][:5])

# %%
import pandas as pd

results=pd.DataFrame.from_dict(results, orient='index')
results.to_csv('results.csv')

# %%
NTT/graph03/anomaly_detection/results.csv
